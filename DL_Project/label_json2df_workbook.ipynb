# %% [markdown]
# <a href="https://colab.research.google.com/github/ElaYJ/Study_Deep_Learning/blob/main/DL_Project/label_json2df_workbook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

json_data_dir = "/content/drive/MyDrive/딥러닝프로젝트/json_label_data/extracted_train"
filename = "C24_B02_005_459161.json"
rm_path = os.path.join(json_data_dir, filename)

if os.path.exists(rm_path):
    os.remove(rm_path)
    print(f"{filename} 삭제")
else:
    print("존재하지 않는 파일")
# Out:
# C24_B02_005_459161.json 삭제

# %%
import os

json_data_dir = "/content/drive/MyDrive/DLP/label_data_json/extracted_train"

json_list = os.listdir(json_data_dir)
json_list[:10], len(json_list)
# Out:
# (['C24_B02_003_753155.json',
#   'C24_B02_002_753133.json',
#   'C24_B02_003_753134.json',
#   'C24_B02_003_753162.json',
#   'C24_B02_005_753144.json',
#   'C24_B02_004_753149.json',
#   'C24_B02_005_753137.json',
#   'C24_B02_006_753138.json',
#   'C24_B02_004_753142.json',
#   'C24_B02_001_753129.json'],
#  24346)

# %%
import json

with open(os.path.join(json_data_dir, json_list[0]), 'r') as f:
    data = json.load(f)

data
# Out:
# {'images': {'image_id': 753155,
#   'farm_id': 'AIF005',
#   'crops_id': 'C24_B02',
#   'crops': '딸기',
#   'kind_type': '금실',
#   'file_path': '/cropsImages/B/B02/AIF005/C24',
#   'fname': 'C24_B02_003_220108151516.jpg',
#   'fext': 'jpg',
#   'width': '1087',
#   'height': '1440',
#   'create_date': '2022-01-10',
#   'date_captured': '2022-01-08 15:15:16',
#   'growth_stage': '출뢰기',
#   'leaf': '1',
#   'plant_body': '0'},
#  'envrionments': [{'farm_id': 'AIF005',
#    'receive_date': '2022-01-08 15:14:29',
#    'id': 0,
#    'ti_value': '21.0',
#    'hi_value': '14.0',
#    'ci_value': '462',
#    'ir_value': None,
#    'tl_value': None,
#    'ei_value': None,
#    'pl_value': None},
#   {'farm_id': 'AIF005',
#    'receive_date': '2022-01-08 15:10:27',
#    'id': 1,
#    'ti_value': '22.0',
#    'hi_value': '12.0',
#    'ci_value': '464',
#    'ir_value': None,
#    'tl_value': None,
#    'ei_value': None,
#    'pl_value': None}],
#  'growth_index': {'corps_id': 'C24_B02',
#   'measured_date': None,
#   'stem_length': None,
#   'leaf_cnt': None,
#   'leaf_width': None,
#   'leaf_length': None,
#   'stem_thick': None,
#   'fr_weight': None},
#  'etc_infor': {'corps_id': 'C24_B02', 'create_date': '', 'inform': ''},
#  'annotations': [{'segmentation': [656.78,
#     685.02,
#     704.33,
#     685.02,
#     704.33,
#     737.15,
#     656.78,
#     737.15],
#    'area': 2479.3,
#    'bbox': [656.78, 685.02, 47.56, 52.13],
#    'isCrowd': 0,
#    'id': 0,
#    'image_id': 753155,
#    'category_id': 0},
#   {'segmentation': [758.65,
#     717.95,
#     837.32,
#     717.95,
#     837.32,
#     832.9,
#     758.65,
#     832.9],
#    'area': 9043.11,
#    'bbox': [758.65, 717.95, 78.67, 114.95],
#    'isCrowd': 0,
#    'id': 1,
#    'image_id': 753155,
#    'category_id': 1},
#   {'segmentation': [806.23,
#     744.79,
#     878.19,
#     744.79,
#     878.19,
#     793.87,
#     806.23,
#     793.87],
#    'area': 3531.79,
#    'bbox': [806.23, 744.79, 71.96, 49.08],
#    'isCrowd': 0,
#    'id': 2,
#    'image_id': 753155,
#    'category_id': 2},
#   {'segmentation': [804.4,
#     674.65,
#     896.49,
#     674.65,
#     896.49,
#     757.27,
#     804.4,
#     757.27],
#    'area': 7608.47,
#    'bbox': [804.4, 674.65, 92.09, 82.62],
#    'isCrowd': 0,
#    'id': 3,
#    'image_id': 753155,
#    'category_id': 3},
#   {'segmentation': [708.02,
#     653.3,
#     754.36,
#     653.3,
#     754.36,
#     702.99,
#     708.02,
#     702.99],
#    'area': 2302.63,
#    'bbox': [708.02, 653.3, 46.34, 49.69],
#    'isCrowd': 0,
#    'id': 4,
#    'image_id': 753155,
#    'category_id': 4},
#   {'segmentation': [763.53,
#     631.34,
#     846.02,
#     631.34,
#     846.02,
#     711.38,
#     763.53,
#     711.38],
#    'area': 6602.49,
#    'bbox': [763.53, 631.34, 82.49, 80.04],
#    'isCrowd': 0,
#    'id': 5,
#    'image_id': 753155,
#    'category_id': 5},
#   {'segmentation': [697.04,
#     586.21,
#     792.79,
#     586.21,
#     792.79,
#     638.95,
#     697.04,
#     638.95],
#    'area': 5049.85,
#    'bbox': [697.04, 586.21, 95.75, 52.74],
#    'isCrowd': 0,
#    'id': 6,
#    'image_id': 753155,
#    'category_id': 6},
#   {'segmentation': [851.37,
#     566.08,
#     916.62,
#     566.08,
#     916.62,
#     624.31,
#     851.37,
#     624.31],
#    'area': 3799.5,
#    'bbox': [851.37, 566.08, 65.25, 58.23],
#    'isCrowd': 0,
#    'id': 7,
#    'image_id': 753155,
#    'category_id': 7},
#   {'segmentation': [997.16,
#     605.12,
#     1020.32,
#     605.12,
#     1020.32,
#     810.94,
#     997.16,
#     810.94],
#    'area': 4766.79,
#    'bbox': [997.16, 605.12, 23.16, 205.82],
#    'isCrowd': 0,
#    'id': 8,
#    'image_id': 753155,
#    'category_id': 8},
#   {'segmentation': [1021.56,
#     581.33,
#     1087,
#     581.33,
#     1087,
#     701.16,
#     1021.56,
#     701.16],
#    'area': 7841.67,
#    'bbox': [1021.56, 581.33, 65.44, 119.83],
#    'isCrowd': 0,
#    'id': 9,
#    'image_id': 753155,
#    'category_id': 9}],
#  'licenses': [{'id': 1, 'name': 'CCMediaService', 'url': ''}],
#  'categories': [{'id': 0, 'name': '화방', 'supercategory': 'none'},
#   {'id': 1, 'name': '과실', 'supercategory': 'none'},
#   {'id': 2, 'name': '과실', 'supercategory': 'none'},
#   {'id': 3, 'name': '과실', 'supercategory': 'none'},
#   {'id': 4, 'name': '화방', 'supercategory': 'none'},
#   {'id': 5, 'name': '화방', 'supercategory': 'none'},
#   {'id': 6, 'name': '잎', 'supercategory': 'none'},
#   {'id': 7, 'name': '줄기', 'supercategory': 'none'},
#   {'id': 8, 'name': '줄기', 'supercategory': 'none'},
#   {'id': 9, 'name': '줄기', 'supercategory': 'none'}]}

# %%
img_id = data['images']['image_id']
farm_id = data['images']['farm_id']
crops_id = data['images']['crops_id']
img_id, farm_id, crops_id
# Out:
# (753155, 'AIF005', 'C24_B02')

# %%
crops_type = data['images']['crops'] +" "+ data['images']['kind_type']
crops_type
# Out:
# '딸기 금실'

# %%
fname = json_list[0].split('.')[0]
fname
# Out:
# 'C24_B02_003_753155'

# %%
img_width = int(data['images']['width'])
img_height = int(data['images']['height'])
img_width, img_height
# Out:
# (1087, 1440)

# %%
from datetime import datetime

date_string = "2021-11-19 15:19:57"
date_time = datetime.strptime(date_string, "%Y-%m-%d %H:%M:%S")

print(date_time, type(date_time))
# Out:
# 2021-11-19 15:19:57 <class 'datetime.datetime'>

# %% [markdown]
# #### - datetime casting
#
# - 파이썬에서 문자열을 datetime 자료형으로 변환하려면 `datetime` 모듈의 `strptime()` 함수를 사용한다.
#
# - 이 함수를 사용하여 문자열을 날짜와 시간으로 파싱할 수 있습니다.
#
# - "2021-11-19 15:19:57" 문자열을 datetime 자료형으로 변환하는 예제
#
#     ```python
#     from datetime import datetime
#
#     date_string = "2021-11-19 15:19:57"
#     date_time = datetime.strptime(date_string, "%Y-%m-%d %H:%M:%S")
#     ```
#     ▷ "2021-11-19 15:19:57" 문자열이 파싱되어 datetime 객체로 저장
#
# - `strptime()` 함수의
#
#     첫 번째 인수로 변환하려는 문자열을,
#
#     두 번째 인수로는 해당 문자열의 형식을 지정하는 포맷 문자열을 전달한다.
#
#     - `%Y`는 네 자리 연도를,
#     - `%m`은 두 자리 월을,
#     - `%d`는 두 자리 일을,
#     - `%H`는 24시간 형식의 시를,
#     - `%M`은 분을,
#     - `%S`는 초를 나타냄.
#
# <br></br>
#
# - `strftime()` 함수는 파이썬의 `datetime` 객체를 문자열로 변환하는 메서드이다.
#
# - 이 함수를 사용하면 `datetime` 객체를 지정된 형식의 문자열로 변환할 수 있습니다.
#
# - 날짜와 시간을 다양한 형식으로 출력하거나 저장해야 하는 경우 `strftime()` 함수를 사용할 수 있다.
#
# - 사용 예제
#
#     ```python
#     from datetime import datetime
#
#     # 현재 시간을 가져옵니다.
#     now = datetime.now()
#
#     # strftime() 함수를 사용하여 현재 시간을 지정된 형식의 문자열로 변환합니다.
#     # 현재 시간을 "연도-월-일 시간:분:초" 형식의 문자열로 저장됩니다.
#     formatted_time = now.strftime("%Y-%m-%d %H:%M:%S")
#     print("현재 시간:", formatted_time)
#     ```
#
#     - `%Y`, `%m`, `%d`, `%H`, `%M`, `%S`는 각각 연도, 월, 일, 시간, 분, 초를 나타냄.

# %%
captured_date = data['images']['date_captured']
captured_date = datetime.strptime(captured_date, "%Y-%m-%d %H:%M:%S")
captured_date
# Out:
# datetime.datetime(2022, 1, 7, 14, 44, 31)

# %%
date = captured_date.date()
time = captured_date.time()
date, time
# Out:
# (datetime.date(2022, 1, 7), datetime.time(14, 44, 31))

# %%
growth_stage = data['images']['growth_stage']
growth_stage
# Out:
# '출뢰기'

# %%
env1_inner_temper = data['envrionments'][0]['ti_value'] # 내부 온도 (℃)
env1_inner_humidi = data['envrionments'][0]['hi_value'] # 내부 습도 (%)
env1_inner_CO2 = data['envrionments'][0]['ci_value'] # 내부 CO₂ (ppm)
env1_inner_light = data['envrionments'][0]['ir_value'] # 광량 (㎛ol/㎥s)
env1_inner_temper, env1_inner_humidi, env1_inner_CO2, env1_inner_light
# Out:
# ('21.0', '14.0', '462', None)

# %%
env2_inner_temper = data['envrionments'][1]['ti_value'] # 내부 온도 (℃)
env2_inner_humidi = data['envrionments'][1]['hi_value'] # 내부 습도 (%)
env2_inner_CO2 = data['envrionments'][1]['ci_value'] # 내부 CO₂ (ppm)
env2_inner_light = data['envrionments'][1]['ir_value'] # 광량 (㎛ol/㎥s)
env2_inner_temper, env2_inner_humidi, env2_inner_CO2, env2_inner_light
# Out:
# ('22.0', '12.0', '464', None)

# %%
environments = data['envrionments']
environments
# Out:
# [{'farm_id': 'AIF005',
#   'receive_date': '2022-01-08 15:14:29',
#   'id': 0,
#   'ti_value': '21.0',
#   'hi_value': '14.0',
#   'ci_value': '462',
#   'ir_value': None,
#   'tl_value': None,
#   'ei_value': None,
#   'pl_value': None},
#  {'farm_id': 'AIF005',
#   'receive_date': '2022-01-08 15:10:27',
#   'id': 1,
#   'ti_value': '22.0',
#   'hi_value': '12.0',
#   'ci_value': '464',
#   'ir_value': None,
#   'tl_value': None,
#   'ei_value': None,
#   'pl_value': None}]

# %%
len(environments[0]), len(environments[1])
# Out:
# (10, 10)

# %%
growth_info = data['growth_index']
growth_info
# Out:
# {'corps_id': 'C24_B02',
#  'measured_date': None,
#  'stem_length': None,
#  'leaf_cnt': None,
#  'leaf_width': None,
#  'leaf_length': None,
#  'stem_thick': None,
#  'fr_weight': None}

# %%
for key, val in growth_info.items():
    print(f"{key} --> {val}")
# Out:
# corps_id --> C24_B02
# measured_date --> None
# stem_length --> None
# leaf_cnt --> None
# leaf_width --> None
# leaf_length --> None
# stem_thick --> None
# fr_weight --> None

# %%
for i, (k, v) in enumerate(growth_info.items()):
    if i==0: continue
    if v: print(f"{k} --> {v}")

# %%
etc_info = data['etc_infor']
etc_info
# Out:
# {'corps_id': 'C24_B02', 'create_date': '', 'inform': ''}

# %%
annotations = data['annotations']
annotations
# Out:
# [{'segmentation': [656.78,
#    685.02,
#    704.33,
#    685.02,
#    704.33,
#    737.15,
#    656.78,
#    737.15],
#   'area': 2479.3,
#   'bbox': [656.78, 685.02, 47.56, 52.13],
#   'isCrowd': 0,
#   'id': 0,
#   'image_id': 753155,
#   'category_id': 0},
#  {'segmentation': [758.65,
#    717.95,
#    837.32,
#    717.95,
#    837.32,
#    832.9,
#    758.65,
#    832.9],
#   'area': 9043.11,
#   'bbox': [758.65, 717.95, 78.67, 114.95],
#   'isCrowd': 0,
#   'id': 1,
#   'image_id': 753155,
#   'category_id': 1},
#  {'segmentation': [806.23,
#    744.79,
#    878.19,
#    744.79,
#    878.19,
#    793.87,
#    806.23,
#    793.87],
#   'area': 3531.79,
#   'bbox': [806.23, 744.79, 71.96, 49.08],
#   'isCrowd': 0,
#   'id': 2,
#   'image_id': 753155,
#   'category_id': 2},
#  {'segmentation': [804.4,
#    674.65,
#    896.49,
#    674.65,
#    896.49,
#    757.27,
#    804.4,
#    757.27],
#   'area': 7608.47,
#   'bbox': [804.4, 674.65, 92.09, 82.62],
#   'isCrowd': 0,
#   'id': 3,
#   'image_id': 753155,
#   'category_id': 3},
#  {'segmentation': [708.02,
#    653.3,
#    754.36,
#    653.3,
#    754.36,
#    702.99,
#    708.02,
#    702.99],
#   'area': 2302.63,
#   'bbox': [708.02, 653.3, 46.34, 49.69],
#   'isCrowd': 0,
#   'id': 4,
#   'image_id': 753155,
#   'category_id': 4},
#  {'segmentation': [763.53,
#    631.34,
#    846.02,
#    631.34,
#    846.02,
#    711.38,
#    763.53,
#    711.38],
#   'area': 6602.49,
#   'bbox': [763.53, 631.34, 82.49, 80.04],
#   'isCrowd': 0,
#   'id': 5,
#   'image_id': 753155,
#   'category_id': 5},
#  {'segmentation': [697.04,
#    586.21,
#    792.79,
#    586.21,
#    792.79,
#    638.95,
#    697.04,
#    638.95],
#   'area': 5049.85,
#   'bbox': [697.04, 586.21, 95.75, 52.74],
#   'isCrowd': 0,
#   'id': 6,
#   'image_id': 753155,
#   'category_id': 6},
#  {'segmentation': [851.37,
#    566.08,
#    916.62,
#    566.08,
#    916.62,
#    624.31,
#    851.37,
#    624.31],
#   'area': 3799.5,
#   'bbox': [851.37, 566.08, 65.25, 58.23],
#   'isCrowd': 0,
#   'id': 7,
#   'image_id': 753155,
#   'category_id': 7},
#  {'segmentation': [997.16,
#    605.12,
#    1020.32,
#    605.12,
#    1020.32,
#    810.94,
#    997.16,
#    810.94],
#   'area': 4766.79,
#   'bbox': [997.16, 605.12, 23.16, 205.82],
#   'isCrowd': 0,
#   'id': 8,
#   'image_id': 753155,
#   'category_id': 8},
#  {'segmentation': [1021.56,
#    581.33,
#    1087,
#    581.33,
#    1087,
#    701.16,
#    1021.56,
#    701.16],
#   'area': 7841.67,
#   'bbox': [1021.56, 581.33, 65.44, 119.83],
#   'isCrowd': 0,
#   'id': 9,
#   'image_id': 753155,
#   'category_id': 9}]

# %%
categories = data['categories']
categories
# Out:
# [{'id': 0, 'name': '화방', 'supercategory': 'none'},
#  {'id': 1, 'name': '과실', 'supercategory': 'none'},
#  {'id': 2, 'name': '과실', 'supercategory': 'none'},
#  {'id': 3, 'name': '과실', 'supercategory': 'none'},
#  {'id': 4, 'name': '화방', 'supercategory': 'none'},
#  {'id': 5, 'name': '화방', 'supercategory': 'none'},
#  {'id': 6, 'name': '잎', 'supercategory': 'none'},
#  {'id': 7, 'name': '줄기', 'supercategory': 'none'},
#  {'id': 8, 'name': '줄기', 'supercategory': 'none'},
#  {'id': 9, 'name': '줄기', 'supercategory': 'none'}]

# %%
for a, c in zip(annotations, categories):
    print(a['image_id'])
    print(a['segmentation'])
    print(a['area'])
    print(a['bbox'])
    print(c['name'])
# Out:
# 753155
# [656.78, 685.02, 704.33, 685.02, 704.33, 737.15, 656.78, 737.15]
# 2479.3
# [656.78, 685.02, 47.56, 52.13]
# 화방
# 753155
# [758.65, 717.95, 837.32, 717.95, 837.32, 832.9, 758.65, 832.9]
# 9043.11
# [758.65, 717.95, 78.67, 114.95]
# 과실
# 753155
# [806.23, 744.79, 878.19, 744.79, 878.19, 793.87, 806.23, 793.87]
# 3531.79
# [806.23, 744.79, 71.96, 49.08]
# 과실
# 753155
# [804.4, 674.65, 896.49, 674.65, 896.49, 757.27, 804.4, 757.27]
# 7608.47
# [804.4, 674.65, 92.09, 82.62]
# 과실
# 753155
# [708.02, 653.3, 754.36, 653.3, 754.36, 702.99, 708.02, 702.99]
# 2302.63
# [708.02, 653.3, 46.34, 49.69]
# 화방
# 753155
# [763.53, 631.34, 846.02, 631.34, 846.02, 711.38, 763.53, 711.38]
# 6602.49
# [763.53, 631.34, 82.49, 80.04]
# 화방
# 753155
# [697.04, 586.21, 792.79, 586.21, 792.79, 638.95, 697.04, 638.95]
# 5049.85
# [697.04, 586.21, 95.75, 52.74]
# 잎
# 753155
# [851.37, 566.08, 916.62, 566.08, 916.62, 624.31, 851.37, 624.31]
# 3799.5
# [851.37, 566.08, 65.25, 58.23]
# 줄기
# 753155
# [997.16, 605.12, 1020.32, 605.12, 1020.32, 810.94, 997.16, 810.94]
# 4766.79
# [997.16, 605.12, 23.16, 205.82]
# 줄기
# 753155
# [1021.56, 581.33, 1087, 581.33, 1087, 701.16, 1021.56, 701.16]
# 7841.67
# [1021.56, 581.33, 65.44, 119.83]
# 줄기

# %%
import json
from tqdm.notebook import tqdm

df_data = dict(
    fname=[], image_id=[], farm_id=[], crops_id=[],
    crops_type=[], growth_stage=[], c_date=[], c_time=[],
    env1=[], env2=[], growth_info=[], etc_info=[],
    img_width=[], img_height=[], bbox_num=[], annotations=[], categories=[]
)
annot_data = dict(
    image_id=[], fname=[],
    segment=[], area=[], bbox=[], category=[]
)
exinfo_json = set()

for jname in tqdm(json_list, desc='Processing'):
    with open(os.path.join(json_data_dir, jname), 'r') as f:
        data = json.load(f)

    f_name = jname.split('.')[0]
    df_data['fname'].append(f_name)
    val = data['images']['image_id']
    df_data['image_id'].append(val if val else None)
    val = data['images']['farm_id']
    df_data['farm_id'].append(val if val else None)
    val = data['images']['crops_id']
    df_data['crops_id'].append(val if val else None)
    val = datetime.strptime(data['images']['date_captured'], "%Y-%m-%d %H:%M:%S")
    df_data['c_date'].append(val.date() if val else None)
    df_data['c_time'].append(val.time() if val else None)
    val = data['images']['crops'] +" "+ data['images']['kind_type']
    df_data['crops_type'].append(val if val else None)
    val = data['images']['growth_stage']
    df_data['growth_stage'].append(val if val else None)
    val = data['envrionments'][0]
    if len(val) > 10:
        exinfo_json.add(jname)
        print(f"{jname} : {val.keys()}")
    df_data['env1'].append(val if val else None)
    val = data['envrionments'][1]
    if len(val) > 10:
        exinfo_json.add(jname)
        print(f"{jname} : {val.keys()}")
    df_data['env2'].append(val if val else None)
    val = data['growth_index']
    df_data['growth_info'].append(val if val else None)
    for i, (k, v) in enumerate(val.items()):
        if i==0: continue
        if v:
            exinfo_json.add(jname)
            print(f"{jname} : {k} --> {v}")
    val = data['etc_infor']
    df_data['etc_info'].append(val if val else None)
    for i, (k, v) in enumerate(val.items()):
        if i==0: continue
        if v:
            exinfo_json.add(jname)
            print(f"{jname} : {k} --> {v}")
    val = int(data['images']['width'])
    df_data['img_width'].append(val if val else None)
    val = int(data['images']['height'])
    df_data['img_height'].append(val if val else None)
    anno = data['annotations']
    cate = data['categories']
    df_data['bbox_num'].append(len(anno))
    df_data['annotations'].append(anno)
    df_data['categories'].append(cate)
    for a, c in zip(anno, cate):
        annot_data['image_id'].append(a['image_id'])
        annot_data['fname'].append(f_name)
        annot_data['segment'].append(a['segmentation'])
        annot_data['area'].append(a['area'])
        annot_data['bbox'].append(a['bbox'])
        annot_data['category'].append(c['name'])
# Out:
# Processing:   0%|          | 0/24346 [00:00<?, ?it/s]
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# C23_B02_006_429175.json : stem_thick --> 14.4
# C23_B02_006_429175.json : bloom1_date --> 2021-09-15
# C23_B02_006_429175.json : fr1_cnt --> 2
# C23_B02_006_429175.json : fr_weight --> 6
# C23_B02_002_429171.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_002_429171.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_002_429171.json : measured_date --> 2021-11-03
# C23_B02_002_429171.json : stem_length --> 27.7
# C23_B02_002_429171.json : leaf_cnt --> 11
# C23_B02_002_429171.json : leaf_width --> 7.8
# C23_B02_002_429171.json : leaf_length --> 10.9
# C23_B02_002_429171.json : stem_thick --> 13.2
# C23_B02_002_429171.json : bloom1_date --> 2021-09-29
# C23_B02_002_429171.json : fr1_cnt --> 7
# C23_B02_002_429171.json : fr_weight --> 7
# C23_B02_005_429964.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_005_429964.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_005_429964.json : measured_date --> 2021-11-03
# C23_B02_005_429964.json : stem_length --> 26.8
# C23_B02_005_429964.json : leaf_cnt --> 11
# C23_B02_005_429964.json : leaf_width --> 10.8
# C23_B02_005_429964.json : leaf_length --> 14.6
# C23_B02_005_429964.json : stem_thick --> 16
# C23_B02_005_429964.json : bloom1_date --> 2021-10-27
# C23_B02_005_429964.json : fr1_cnt --> 1
# C23_B02_003_429966.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_003_429966.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_003_429966.json : measured_date --> 2021-11-03
# C23_B02_003_429966.json : stem_length --> 36.5
# C23_B02_003_429966.json : leaf_cnt --> 11
# C23_B02_003_429966.json : leaf_width --> 11.2
# C23_B02_003_429966.json : leaf_length --> 16.8
# C23_B02_003_429966.json : stem_thick --> 16
# C23_B02_003_429966.json : bloom1_date --> 2021-11-03
# C23_B02_002_429967.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_002_429967.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_002_429967.json : measured_date --> 2021-11-03
# C23_B02_002_429967.json : stem_length --> 27.7
# C23_B02_002_429967.json : leaf_cnt --> 11
# C23_B02_002_429967.json : leaf_width --> 7.8
# C23_B02_002_429967.json : leaf_length --> 10.9
# C23_B02_002_429967.json : stem_thick --> 13.2
# C23_B02_002_429967.json : bloom1_date --> 2021-09-29
# C23_B02_002_429967.json : fr1_cnt --> 7
# C23_B02_002_429967.json : fr_weight --> 7
# C23_B02_006_429963.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_006_429963.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_006_429963.json : measured_date --> 2021-11-03
# C23_B02_006_429963.json : stem_length --> 29
# C23_B02_006_429963.json : leaf_cnt --> 14
# C23_B02_006_429963.json : leaf_width --> 8.7
# C23_B02_006_429963.json : leaf_length --> 13.6
# C23_B02_006_429963.json : stem_thick --> 14.4
# C23_B02_006_429963.json : bloom1_date --> 2021-09-15
# C23_B02_006_429963.json : fr1_cnt --> 2
# C23_B02_006_429963.json : fr_weight --> 6
# C23_B02_001_429968.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_001_429968.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_001_429968.json : measured_date --> 2021-11-03
# C23_B02_001_429968.json : stem_length --> 28.5
# C23_B02_001_429968.json : leaf_cnt --> 15
# C23_B02_001_429968.json : leaf_width --> 8.2
# C23_B02_001_429968.json : leaf_length --> 11
# C23_B02_001_429968.json : stem_thick --> 14.6
# C23_B02_001_429968.json : bloom1_date --> 2021-09-01
# C23_B02_001_429968.json : fr1_cnt --> 2
# C23_B02_001_429968.json : fr_weight --> 2
# C23_B02_006_430765.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_006_430765.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_006_430765.json : measured_date --> 2021-10-27
# C23_B02_006_430765.json : stem_length --> 29.8
# C23_B02_006_430765.json : leaf_cnt --> 13
# C23_B02_006_430765.json : leaf_width --> 8.3
# C23_B02_006_430765.json : leaf_length --> 12.7
# C23_B02_006_430765.json : stem_thick --> 15
# C23_B02_006_430765.json : bloom1_date --> 2021-09-15
# C23_B02_006_430765.json : fr1_cnt --> 2
# C23_B02_006_430765.json : fr_weight --> 14
# C23_B02_001_430763.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_001_430763.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_001_430763.json : measured_date --> 2021-10-27
# C23_B02_001_430763.json : stem_length --> 29.3
# C23_B02_001_430763.json : leaf_cnt --> 11
# C23_B02_001_430763.json : leaf_width --> 10.1
# C23_B02_001_430763.json : leaf_length --> 10.2
# C23_B02_001_430763.json : stem_thick --> 16.4
# C23_B02_001_430763.json : bloom1_date --> 2021-09-01
# C23_B02_001_430763.json : fr1_cnt --> 3
# C23_B02_001_430770.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_001_430770.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_001_430770.json : measured_date --> 2021-10-27
# C23_B02_001_430770.json : stem_length --> 29.3
# C23_B02_001_430770.json : leaf_cnt --> 11
# C23_B02_001_430770.json : leaf_width --> 10.1
# C23_B02_001_430770.json : leaf_length --> 10.2
# C23_B02_001_430770.json : stem_thick --> 16.4
# C23_B02_001_430770.json : bloom1_date --> 2021-09-01
# C23_B02_001_430770.json : fr1_cnt --> 3
# C23_B02_006_430758.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_006_430758.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_006_430758.json : measured_date --> 2021-10-27
# C23_B02_006_430758.json : stem_length --> 29.8
# C23_B02_006_430758.json : leaf_cnt --> 13
# C23_B02_006_430758.json : leaf_width --> 8.3
# C23_B02_006_430758.json : leaf_length --> 12.7
# C23_B02_006_430758.json : stem_thick --> 15
# C23_B02_006_430758.json : bloom1_date --> 2021-09-15
# C23_B02_006_430758.json : fr1_cnt --> 2
# C23_B02_006_430758.json : fr_weight --> 14
# C23_B02_003_430761.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_003_430761.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_003_430761.json : measured_date --> 2021-10-27
# C23_B02_003_430761.json : stem_length --> 36
# C23_B02_003_430761.json : leaf_cnt --> 11
# C23_B02_003_430761.json : leaf_width --> 9.4
# C23_B02_003_430761.json : leaf_length --> 12.4
# C23_B02_003_430761.json : stem_thick --> 16.6
# C23_B02_005_430766.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_005_430766.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_005_430766.json : measured_date --> 2021-10-27
# C23_B02_005_430766.json : stem_length --> 29.6
# C23_B02_005_430766.json : leaf_cnt --> 9
# C23_B02_005_430766.json : leaf_width --> 9.5
# C23_B02_005_430766.json : leaf_length --> 11
# C23_B02_005_430766.json : stem_thick --> 15.4
# C23_B02_005_430766.json : bloom1_date --> 2021-10-27
# C23_B02_002_430769.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_002_430769.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_002_430769.json : measured_date --> 2021-10-27
# C23_B02_002_430769.json : stem_length --> 28
# C23_B02_002_430769.json : leaf_cnt --> 11
# C23_B02_002_430769.json : leaf_width --> 8.6
# C23_B02_002_430769.json : leaf_length --> 11.5
# C23_B02_002_430769.json : stem_thick --> 13.7
# C23_B02_002_430769.json : bloom1_date --> 2021-09-29
# C23_B02_002_430769.json : fr1_cnt --> 8
# C23_B02_002_430769.json : fr_weight --> 40
# C23_B02_002_430762.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_002_430762.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_002_430762.json : measured_date --> 2021-10-27
# C23_B02_002_430762.json : stem_length --> 28
# C23_B02_002_430762.json : leaf_cnt --> 11
# C23_B02_002_430762.json : leaf_width --> 8.6
# C23_B02_002_430762.json : leaf_length --> 11.5
# C23_B02_002_430762.json : stem_thick --> 13.7
# C23_B02_002_430762.json : bloom1_date --> 2021-09-29
# C23_B02_002_430762.json : fr1_cnt --> 8
# C23_B02_002_430762.json : fr_weight --> 40
# C23_B02_005_430773.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_005_430773.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_005_430773.json : measured_date --> 2021-10-27
# C23_B02_005_430773.json : stem_length --> 29.6
# C23_B02_005_430773.json : leaf_cnt --> 9
# C23_B02_005_430773.json : leaf_width --> 9.5
# C23_B02_005_430773.json : leaf_length --> 11
# C23_B02_005_430773.json : stem_thick --> 15.4
# C23_B02_005_430773.json : bloom1_date --> 2021-10-27
# C23_B02_002_430795.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_002_430795.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_002_430795.json : measured_date --> 2021-10-27
# C23_B02_002_430795.json : stem_length --> 28
# C23_B02_002_430795.json : leaf_cnt --> 11
# C23_B02_002_430795.json : leaf_width --> 8.6
# C23_B02_002_430795.json : leaf_length --> 11.5
# C23_B02_002_430795.json : stem_thick --> 13.7
# C23_B02_002_430795.json : bloom1_date --> 2021-09-29
# C23_B02_002_430795.json : fr1_cnt --> 8
# C23_B02_002_430795.json : fr_weight --> 40
# C23_B02_002_430776.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_002_430776.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_002_430776.json : measured_date --> 2021-10-27
# C23_B02_002_430776.json : stem_length --> 28
# C23_B02_002_430776.json : leaf_cnt --> 11
# C23_B02_002_430776.json : leaf_width --> 8.6
# C23_B02_002_430776.json : leaf_length --> 11.5
# C23_B02_002_430776.json : stem_thick --> 13.7
# C23_B02_002_430776.json : bloom1_date --> 2021-09-29
# C23_B02_002_430776.json : fr1_cnt --> 8
# C23_B02_002_430776.json : fr_weight --> 40
# C23_B02_001_430796.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_001_430796.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_001_430796.json : measured_date --> 2021-10-27
# C23_B02_001_430796.json : stem_length --> 29.3
# C23_B02_001_430796.json : leaf_cnt --> 11
# C23_B02_001_430796.json : leaf_width --> 10.1
# C23_B02_001_430796.json : leaf_length --> 10.2
# C23_B02_001_430796.json : stem_thick --> 16.4
# C23_B02_001_430796.json : bloom1_date --> 2021-09-01
# C23_B02_001_430796.json : fr1_cnt --> 3
# C23_B02_005_430827.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_005_430827.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_005_430827.json : measured_date --> 2021-10-27
# C23_B02_005_430827.json : stem_length --> 29.6
# C23_B02_005_430827.json : leaf_cnt --> 9
# C23_B02_005_430827.json : leaf_width --> 9.5
# C23_B02_005_430827.json : leaf_length --> 11
# C23_B02_005_430827.json : stem_thick --> 15.4
# C23_B02_005_430827.json : bloom1_date --> 2021-10-27
# C23_B02_006_430791.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_006_430791.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_006_430791.json : measured_date --> 2021-10-27
# C23_B02_006_430791.json : stem_length --> 29.8
# C23_B02_006_430791.json : leaf_cnt --> 13
# C23_B02_006_430791.json : leaf_width --> 8.3
# C23_B02_006_430791.json : leaf_length --> 12.7
# C23_B02_006_430791.json : stem_thick --> 15
# C23_B02_006_430791.json : bloom1_date --> 2021-09-15
# C23_B02_006_430791.json : fr1_cnt --> 2
# C23_B02_006_430791.json : fr_weight --> 14
# C23_B02_006_430826.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_006_430826.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_006_430826.json : measured_date --> 2021-10-27
# C23_B02_006_430826.json : stem_length --> 29.8
# C23_B02_006_430826.json : leaf_cnt --> 13
# C23_B02_006_430826.json : leaf_width --> 8.3
# C23_B02_006_430826.json : leaf_length --> 12.7
# C23_B02_006_430826.json : stem_thick --> 15
# C23_B02_006_430826.json : bloom1_date --> 2021-09-15
# C23_B02_006_430826.json : fr1_cnt --> 2
# C23_B02_006_430826.json : fr_weight --> 14
# C23_B02_003_430794.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_003_430794.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_003_430794.json : measured_date --> 2021-10-27
# C23_B02_003_430794.json : stem_length --> 36
# C23_B02_003_430794.json : leaf_cnt --> 11
# C23_B02_003_430794.json : leaf_width --> 9.4
# C23_B02_003_430794.json : leaf_length --> 12.4
# C23_B02_003_430794.json : stem_thick --> 16.6
# C23_B02_006_430772.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_006_430772.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_006_430772.json : measured_date --> 2021-10-27
# C23_B02_006_430772.json : stem_length --> 29.8
# C23_B02_006_430772.json : leaf_cnt --> 13
# C23_B02_006_430772.json : leaf_width --> 8.3
# C23_B02_006_430772.json : leaf_length --> 12.7
# C23_B02_006_430772.json : stem_thick --> 15
# C23_B02_006_430772.json : bloom1_date --> 2021-09-15
# C23_B02_006_430772.json : fr1_cnt --> 2
# C23_B02_006_430772.json : fr_weight --> 14
# C23_B02_001_430777.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_001_430777.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_001_430777.json : measured_date --> 2021-10-27
# C23_B02_001_430777.json : stem_length --> 29.3
# C23_B02_001_430777.json : leaf_cnt --> 11
# C23_B02_001_430777.json : leaf_width --> 10.1
# C23_B02_001_430777.json : leaf_length --> 10.2
# C23_B02_001_430777.json : stem_thick --> 16.4
# C23_B02_001_430777.json : bloom1_date --> 2021-09-01
# C23_B02_001_430777.json : fr1_cnt --> 3
# C23_B02_005_430792.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_005_430792.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_005_430792.json : measured_date --> 2021-10-27
# C23_B02_005_430792.json : stem_length --> 29.6
# C23_B02_005_430792.json : leaf_cnt --> 9
# C23_B02_005_430792.json : leaf_width --> 9.5
# C23_B02_005_430792.json : leaf_length --> 11
# C23_B02_005_430792.json : stem_thick --> 15.4
# C23_B02_005_430792.json : bloom1_date --> 2021-10-27
# C23_B02_003_430775.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_003_430775.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_003_430775.json : measured_date --> 2021-10-27
# C23_B02_003_430775.json : stem_length --> 36
# C23_B02_003_430775.json : leaf_cnt --> 11
# C23_B02_003_430775.json : leaf_width --> 9.4
# C23_B02_003_430775.json : leaf_length --> 12.4
# C23_B02_003_430775.json : stem_thick --> 16.6
# C23_B02_005_430834.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_005_430834.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_005_430834.json : measured_date --> 2021-10-27
# C23_B02_005_430834.json : stem_length --> 29.6
# C23_B02_005_430834.json : leaf_cnt --> 9
# C23_B02_005_430834.json : leaf_width --> 9.5
# C23_B02_005_430834.json : leaf_length --> 11
# C23_B02_005_430834.json : stem_thick --> 15.4
# C23_B02_005_430834.json : bloom1_date --> 2021-10-27
# C23_B02_002_430837.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_002_430837.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_002_430837.json : measured_date --> 2021-10-27
# C23_B02_002_430837.json : stem_length --> 28
# C23_B02_002_430837.json : leaf_cnt --> 11
# C23_B02_002_430837.json : leaf_width --> 8.6
# C23_B02_002_430837.json : leaf_length --> 11.5
# C23_B02_002_430837.json : stem_thick --> 13.7
# C23_B02_002_430837.json : bloom1_date --> 2021-09-29
# C23_B02_002_430837.json : fr1_cnt --> 8
# C23_B02_002_430837.json : fr_weight --> 40
# C23_B02_001_430838.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_001_430838.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_001_430838.json : measured_date --> 2021-10-27
# C23_B02_001_430838.json : stem_length --> 29.3
# C23_B02_001_430838.json : leaf_cnt --> 11
# C23_B02_001_430838.json : leaf_width --> 10.1
# C23_B02_001_430838.json : leaf_length --> 10.2
# C23_B02_001_430838.json : stem_thick --> 16.4
# C23_B02_001_430838.json : bloom1_date --> 2021-09-01
# C23_B02_001_430838.json : fr1_cnt --> 3
# C23_B02_003_430836.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_003_430836.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_003_430836.json : measured_date --> 2021-10-27
# C23_B02_003_430836.json : stem_length --> 36
# C23_B02_003_430836.json : leaf_cnt --> 11
# C23_B02_003_430836.json : leaf_width --> 9.4
# C23_B02_003_430836.json : leaf_length --> 12.4
# C23_B02_003_430836.json : stem_thick --> 16.6
# C23_B02_003_430829.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_003_430829.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_003_430829.json : measured_date --> 2021-10-27
# C23_B02_003_430829.json : stem_length --> 36
# C23_B02_003_430829.json : leaf_cnt --> 11
# C23_B02_003_430829.json : leaf_width --> 9.4
# C23_B02_003_430829.json : leaf_length --> 12.4
# C23_B02_003_430829.json : stem_thick --> 16.6
# C23_B02_006_430833.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_006_430833.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_006_430833.json : measured_date --> 2021-10-27
# C23_B02_006_430833.json : stem_length --> 29.8
# C23_B02_006_430833.json : leaf_cnt --> 13
# C23_B02_006_430833.json : leaf_width --> 8.3
# C23_B02_006_430833.json : leaf_length --> 12.7
# C23_B02_006_430833.json : stem_thick --> 15
# C23_B02_006_430833.json : bloom1_date --> 2021-09-15
# C23_B02_006_430833.json : fr1_cnt --> 2
# C23_B02_006_430833.json : fr_weight --> 14
# C23_B02_001_430831.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_001_430831.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_001_430831.json : measured_date --> 2021-10-27
# C23_B02_001_430831.json : stem_length --> 29.3
# C23_B02_001_430831.json : leaf_cnt --> 11
# C23_B02_001_430831.json : leaf_width --> 10.1
# C23_B02_001_430831.json : leaf_length --> 10.2
# C23_B02_001_430831.json : stem_thick --> 16.4
# C23_B02_001_430831.json : bloom1_date --> 2021-09-01
# C23_B02_001_430831.json : fr1_cnt --> 3
# C23_B02_002_430830.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_002_430830.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_002_430830.json : measured_date --> 2021-10-27
# C23_B02_002_430830.json : stem_length --> 28
# C23_B02_002_430830.json : leaf_cnt --> 11
# C23_B02_002_430830.json : leaf_width --> 8.6
# C23_B02_002_430830.json : leaf_length --> 11.5
# C23_B02_002_430830.json : stem_thick --> 13.7
# C23_B02_002_430830.json : bloom1_date --> 2021-09-29
# C23_B02_002_430830.json : fr1_cnt --> 8
# C23_B02_002_430830.json : fr_weight --> 40
# C23_B02_005_431119.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_005_431119.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_005_431119.json : measured_date --> 2021-10-27
# C23_B02_005_431119.json : stem_length --> 29.6
# C23_B02_005_431119.json : leaf_cnt --> 9
# C23_B02_005_431119.json : leaf_width --> 9.5
# C23_B02_005_431119.json : leaf_length --> 11
# C23_B02_005_431119.json : stem_thick --> 15.4
# C23_B02_005_431119.json : bloom1_date --> 2021-10-27
# C23_B02_003_431132.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_003_431132.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_003_431132.json : measured_date --> 2021-10-27
# C23_B02_003_431132.json : stem_length --> 36
# C23_B02_003_431132.json : leaf_cnt --> 11
# C23_B02_003_431132.json : leaf_width --> 9.4
# C23_B02_003_431132.json : leaf_length --> 12.4
# C23_B02_003_431132.json : stem_thick --> 16.6
# C23_B02_003_431121.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_003_431121.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_003_431121.json : measured_date --> 2021-10-27
# C23_B02_003_431121.json : stem_length --> 36
# C23_B02_003_431121.json : leaf_cnt --> 11
# C23_B02_003_431121.json : leaf_width --> 9.4
# C23_B02_003_431121.json : leaf_length --> 12.4
# C23_B02_003_431121.json : stem_thick --> 16.6
# C23_B02_001_431134.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_001_431134.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_001_431134.json : measured_date --> 2021-10-27
# C23_B02_001_431134.json : stem_length --> 29.3
# C23_B02_001_431134.json : leaf_cnt --> 11
# C23_B02_001_431134.json : leaf_width --> 10.1
# C23_B02_001_431134.json : leaf_length --> 10.2
# C23_B02_001_431134.json : stem_thick --> 16.4
# C23_B02_001_431134.json : bloom1_date --> 2021-09-01
# C23_B02_001_431134.json : fr1_cnt --> 3
# C23_B02_006_431118.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_006_431118.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_006_431118.json : measured_date --> 2021-10-27
# C23_B02_006_431118.json : stem_length --> 29.8
# C23_B02_006_431118.json : leaf_cnt --> 13
# C23_B02_006_431118.json : leaf_width --> 8.3
# C23_B02_006_431118.json : leaf_length --> 12.7
# C23_B02_006_431118.json : stem_thick --> 15
# C23_B02_006_431118.json : bloom1_date --> 2021-09-15
# C23_B02_006_431118.json : fr1_cnt --> 2
# C23_B02_006_431118.json : fr_weight --> 14
# C23_B02_006_431157.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_006_431157.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_006_431157.json : measured_date --> 2021-10-27
# C23_B02_006_431157.json : stem_length --> 29.8
# C23_B02_006_431157.json : leaf_cnt --> 13
# C23_B02_006_431157.json : leaf_width --> 8.3
# C23_B02_006_431157.json : leaf_length --> 12.7
# C23_B02_006_431157.json : stem_thick --> 15
# C23_B02_006_431157.json : bloom1_date --> 2021-09-15
# C23_B02_006_431157.json : fr1_cnt --> 2
# C23_B02_006_431157.json : fr_weight --> 14
# C23_B02_002_431122.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_002_431122.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_002_431122.json : measured_date --> 2021-10-27
# C23_B02_002_431122.json : stem_length --> 28
# C23_B02_002_431122.json : leaf_cnt --> 11
# C23_B02_002_431122.json : leaf_width --> 8.6
# C23_B02_002_431122.json : leaf_length --> 11.5
# C23_B02_002_431122.json : stem_thick --> 13.7
# C23_B02_002_431122.json : bloom1_date --> 2021-09-29
# C23_B02_002_431122.json : fr1_cnt --> 8
# C23_B02_002_431122.json : fr_weight --> 40
# C23_B02_002_431133.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_002_431133.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_002_431133.json : measured_date --> 2021-10-27
# C23_B02_002_431133.json : stem_length --> 28
# C23_B02_002_431133.json : leaf_cnt --> 11
# C23_B02_002_431133.json : leaf_width --> 8.6
# C23_B02_002_431133.json : leaf_length --> 11.5
# C23_B02_002_431133.json : stem_thick --> 13.7
# C23_B02_002_431133.json : bloom1_date --> 2021-09-29
# C23_B02_002_431133.json : fr1_cnt --> 8
# C23_B02_002_431133.json : fr_weight --> 40
# C23_B02_005_431158.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_005_431158.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_005_431158.json : measured_date --> 2021-10-27
# C23_B02_005_431158.json : stem_length --> 29.6
# C23_B02_005_431158.json : leaf_cnt --> 9
# C23_B02_005_431158.json : leaf_width --> 9.5
# C23_B02_005_431158.json : leaf_length --> 11
# C23_B02_005_431158.json : stem_thick --> 15.4
# C23_B02_005_431158.json : bloom1_date --> 2021-10-27
# C23_B02_005_431174.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_005_431174.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_005_431174.json : measured_date --> 2021-10-27
# C23_B02_005_431174.json : stem_length --> 29.6
# C23_B02_005_431174.json : leaf_cnt --> 9
# C23_B02_005_431174.json : leaf_width --> 9.5
# C23_B02_005_431174.json : leaf_length --> 11
# C23_B02_005_431174.json : stem_thick --> 15.4
# C23_B02_005_431174.json : bloom1_date --> 2021-10-27
# C23_B02_002_431161.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_002_431161.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_002_431161.json : measured_date --> 2021-10-27
# C23_B02_002_431161.json : stem_length --> 28
# C23_B02_002_431161.json : leaf_cnt --> 11
# C23_B02_002_431161.json : leaf_width --> 8.6
# C23_B02_002_431161.json : leaf_length --> 11.5
# C23_B02_002_431161.json : stem_thick --> 13.7
# C23_B02_002_431161.json : bloom1_date --> 2021-09-29
# C23_B02_002_431161.json : fr1_cnt --> 8
# C23_B02_002_431161.json : fr_weight --> 40
# C23_B02_002_431177.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_002_431177.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_002_431177.json : measured_date --> 2021-10-27
# C23_B02_002_431177.json : stem_length --> 28
# C23_B02_002_431177.json : leaf_cnt --> 11
# C23_B02_002_431177.json : leaf_width --> 8.6
# C23_B02_002_431177.json : leaf_length --> 11.5
# C23_B02_002_431177.json : stem_thick --> 13.7
# C23_B02_002_431177.json : bloom1_date --> 2021-09-29
# C23_B02_002_431177.json : fr1_cnt --> 8
# C23_B02_002_431177.json : fr_weight --> 40
# C23_B02_001_431178.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_001_431178.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_001_431178.json : measured_date --> 2021-10-27
# C23_B02_001_431178.json : stem_length --> 29.3
# C23_B02_001_431178.json : leaf_cnt --> 11
# C23_B02_001_431178.json : leaf_width --> 10.1
# C23_B02_001_431178.json : leaf_length --> 10.2
# C23_B02_001_431178.json : stem_thick --> 16.4
# C23_B02_001_431178.json : bloom1_date --> 2021-09-01
# C23_B02_001_431178.json : fr1_cnt --> 3
# C23_B02_001_431162.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_001_431162.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_001_431162.json : measured_date --> 2021-10-27
# C23_B02_001_431162.json : stem_length --> 29.3
# C23_B02_001_431162.json : leaf_cnt --> 11
# C23_B02_001_431162.json : leaf_width --> 10.1
# C23_B02_001_431162.json : leaf_length --> 10.2
# C23_B02_001_431162.json : stem_thick --> 16.4
# C23_B02_001_431162.json : bloom1_date --> 2021-09-01
# C23_B02_001_431162.json : fr1_cnt --> 3
# C23_B02_006_431173.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_006_431173.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_006_431173.json : measured_date --> 2021-10-27
# C23_B02_006_431173.json : stem_length --> 29.8
# C23_B02_006_431173.json : leaf_cnt --> 13
# C23_B02_006_431173.json : leaf_width --> 8.3
# C23_B02_006_431173.json : leaf_length --> 12.7
# C23_B02_006_431173.json : stem_thick --> 15
# C23_B02_006_431173.json : bloom1_date --> 2021-09-15
# C23_B02_006_431173.json : fr1_cnt --> 2
# C23_B02_006_431173.json : fr_weight --> 14
# C23_B02_003_431176.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_003_431176.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C23_B02_003_431176.json : measured_date --> 2021-10-27
# C23_B02_003_431176.json : stem_length --> 36
# C23_B02_003_431176.json : leaf_cnt --> 11
# C23_B02_003_431176.json : leaf_width --> 9.4
# C23_B02_003_431176.json : leaf_length --> 12.4
# C23_B02_003_431176.json : stem_thick --> 16.6
# C24_B02_004_427014.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C24_B02_004_427014.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C24_B02_004_427014.json : measured_date --> 2021-11-03
# C24_B02_004_427014.json : stem_length --> 34.5
# C24_B02_004_427014.json : leaf_cnt --> 16
# C24_B02_004_427014.json : leaf_width --> 10.3
# C24_B02_004_427014.json : leaf_length --> 13.6
# C24_B02_004_427014.json : stem_thick --> 14.5
# C24_B02_004_427014.json : bloom1_date --> 2021-11-03
# C24_B02_003_427015.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C24_B02_003_427015.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C24_B02_003_427015.json : measured_date --> 2021-11-03
# C24_B02_003_427015.json : stem_length --> 36
# C24_B02_003_427015.json : leaf_cnt --> 18
# C24_B02_003_427015.json : leaf_width --> 11.6
# C24_B02_003_427015.json : leaf_length --> 16.9
# C24_B02_003_427015.json : stem_thick --> 7.6
# C24_B02_003_427015.json : bloom1_date --> 2021-11-03
# C24_B02_003_427015.json : fr1_cnt --> 1
# C24_B02_006_427012.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C24_B02_006_427012.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C24_B02_006_427012.json : measured_date --> 2021-11-03
# C24_B02_006_427012.json : stem_length --> 31
# C24_B02_006_427012.json : leaf_cnt --> 12
# C24_B02_006_427012.json : leaf_width --> 9.8
# C24_B02_006_427012.json : leaf_length --> 14.3
# C24_B02_006_427012.json : stem_thick --> 14.8
# C24_B02_006_427012.json : bloom1_date --> 2021-09-29
# C24_B02_006_427012.json : fr1_cnt --> 6
# C24_B02_006_427012.json : fr_weight --> 11
# C24_B02_005_427013.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C24_B02_005_427013.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C24_B02_005_427013.json : measured_date --> 2021-11-03
# C24_B02_005_427013.json : stem_length --> 28.4
# C24_B02_005_427013.json : leaf_cnt --> 9
# C24_B02_005_427013.json : leaf_width --> 8.8
# C24_B02_005_427013.json : leaf_length --> 13.5
# C24_B02_005_427013.json : stem_thick --> 13.8
# C24_B02_005_427013.json : bloom1_date --> 2021-09-29
# C24_B02_005_427013.json : fr1_cnt --> 7
# C24_B02_005_427013.json : fr_weight --> 5
# C24_B02_002_427016.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C24_B02_002_427016.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C24_B02_002_427016.json : measured_date --> 2021-11-03
# C24_B02_002_427016.json : stem_length --> 26
# C24_B02_002_427016.json : leaf_cnt --> 12
# C24_B02_002_427016.json : leaf_width --> 9.1
# C24_B02_002_427016.json : leaf_length --> 13.2
# C24_B02_002_427016.json : stem_thick --> 16.6
# C24_B02_002_427016.json : bloom1_date --> 2021-11-03
# C24_B02_001_427031.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C24_B02_001_427031.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C24_B02_001_427031.json : measured_date --> 2021-11-03
# C24_B02_001_427031.json : stem_length --> 33
# C24_B02_001_427031.json : leaf_cnt --> 8
# C24_B02_001_427031.json : leaf_width --> 11.1
# C24_B02_001_427031.json : leaf_length --> 16.8
# C24_B02_001_427031.json : stem_thick --> 14.3
# C24_B02_006_427019.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C24_B02_006_427019.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C24_B02_006_427019.json : measured_date --> 2021-11-03
# C24_B02_006_427019.json : stem_length --> 31
# C24_B02_006_427019.json : leaf_cnt --> 12
# C24_B02_006_427019.json : leaf_width --> 9.8
# C24_B02_006_427019.json : leaf_length --> 14.3
# C24_B02_006_427019.json : stem_thick --> 14.8
# C24_B02_006_427019.json : bloom1_date --> 2021-09-29
# C24_B02_006_427019.json : fr1_cnt --> 6
# C24_B02_006_427019.json : fr_weight --> 11
# C24_B02_003_427029.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C24_B02_003_427029.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C24_B02_003_427029.json : measured_date --> 2021-11-03
# C24_B02_003_427029.json : stem_length --> 36
# C24_B02_003_427029.json : leaf_cnt --> 18
# C24_B02_003_427029.json : leaf_width --> 11.6
# C24_B02_003_427029.json : leaf_length --> 16.9
# ...
# C22_B02_004_416409.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_004_416409.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_004_416409.json : measured_date --> 2021-09-29
# C22_B02_004_416409.json : stem_length --> 21.8
# C22_B02_004_416409.json : leaf_cnt --> 6
# C22_B02_004_416409.json : leaf_width --> 7.6
# C22_B02_004_416409.json : leaf_length --> 9.7
# C22_B02_004_416409.json : stem_thick --> 14.4
# C22_B02_004_416409.json : bloom1_date --> 2021-08-25
# C22_B02_004_416409.json : fr1_cnt --> 2
# C22_B02_004_416409.json : fr_weight --> 8
# C22_B02_005_416396.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_005_416396.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_005_416396.json : measured_date --> 2021-09-29
# C22_B02_005_416396.json : stem_length --> 35.5
# C22_B02_005_416396.json : leaf_cnt --> 9
# C22_B02_005_416396.json : leaf_width --> 8
# C22_B02_005_416396.json : leaf_length --> 11.2
# C22_B02_005_416396.json : stem_thick --> 15.3
# C22_B02_005_416396.json : bloom1_date --> 2021-09-23
# C22_B02_005_416396.json : fr1_cnt --> 4
# C22_B02_006_416404.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_006_416404.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_006_416404.json : measured_date --> 2021-09-29
# C22_B02_006_416404.json : stem_length --> 36
# C22_B02_006_416404.json : leaf_cnt --> 9
# C22_B02_006_416404.json : leaf_width --> 9
# C22_B02_006_416404.json : leaf_length --> 13.3
# C22_B02_006_416404.json : stem_thick --> 16.6
# C22_B02_005_416403.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_005_416403.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_005_416403.json : measured_date --> 2021-09-29
# C22_B02_005_416403.json : stem_length --> 35.5
# C22_B02_005_416403.json : leaf_cnt --> 9
# C22_B02_005_416403.json : leaf_width --> 8
# C22_B02_005_416403.json : leaf_length --> 11.2
# C22_B02_005_416403.json : stem_thick --> 15.3
# C22_B02_005_416403.json : bloom1_date --> 2021-09-23
# C22_B02_005_416403.json : fr1_cnt --> 4
# C22_B02_003_416415.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_003_416415.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_003_416415.json : measured_date --> 2021-09-29
# C22_B02_003_416415.json : stem_length --> 34
# C22_B02_003_416415.json : leaf_cnt --> 8
# C22_B02_003_416415.json : leaf_width --> 11.5
# C22_B02_003_416415.json : leaf_length --> 16.5
# C22_B02_003_416415.json : stem_thick --> 15.5
# C22_B02_007_416419.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_007_416419.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_007_416419.json : measured_date --> 2021-09-29
# C22_B02_007_416419.json : stem_length --> 38
# C22_B02_007_416419.json : leaf_cnt --> 7
# C22_B02_007_416419.json : leaf_width --> 8.5
# C22_B02_007_416419.json : leaf_length --> 11.4
# C22_B02_007_416419.json : stem_thick --> 12.3
# C22_B02_007_416419.json : bloom1_date --> 2021-08-25
# C22_B02_007_416419.json : bloom2_date --> 2021-09-23
# C22_B02_007_416419.json : fr1_cnt --> 4
# C22_B02_006_416432.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_006_416432.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_006_416432.json : measured_date --> 2021-09-29
# C22_B02_006_416432.json : stem_length --> 36
# C22_B02_006_416432.json : leaf_cnt --> 9
# C22_B02_006_416432.json : leaf_width --> 9
# C22_B02_006_416432.json : leaf_length --> 13.3
# C22_B02_006_416432.json : stem_thick --> 16.6
# C22_B02_006_416418.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_006_416418.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_006_416418.json : measured_date --> 2021-09-29
# C22_B02_006_416418.json : stem_length --> 36
# C22_B02_006_416418.json : leaf_cnt --> 9
# C22_B02_006_416418.json : leaf_width --> 9
# C22_B02_006_416418.json : leaf_length --> 13.3
# C22_B02_006_416418.json : stem_thick --> 16.6
# C22_B02_006_416411.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_006_416411.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_006_416411.json : measured_date --> 2021-09-29
# C22_B02_006_416411.json : stem_length --> 36
# C22_B02_006_416411.json : leaf_cnt --> 9
# C22_B02_006_416411.json : leaf_width --> 9
# C22_B02_006_416411.json : leaf_length --> 13.3
# C22_B02_006_416411.json : stem_thick --> 16.6
# C22_B02_004_416423.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_004_416423.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_004_416423.json : measured_date --> 2021-09-29
# C22_B02_004_416423.json : stem_length --> 21.8
# C22_B02_004_416423.json : leaf_cnt --> 6
# C22_B02_004_416423.json : leaf_width --> 7.6
# C22_B02_004_416423.json : leaf_length --> 9.7
# C22_B02_004_416423.json : stem_thick --> 14.4
# C22_B02_004_416423.json : bloom1_date --> 2021-08-25
# C22_B02_004_416423.json : fr1_cnt --> 2
# C22_B02_004_416423.json : fr_weight --> 8
# C22_B02_005_416417.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_005_416417.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_005_416417.json : measured_date --> 2021-09-29
# C22_B02_005_416417.json : stem_length --> 35.5
# C22_B02_005_416417.json : leaf_cnt --> 9
# C22_B02_005_416417.json : leaf_width --> 8
# C22_B02_005_416417.json : leaf_length --> 11.2
# C22_B02_005_416417.json : stem_thick --> 15.3
# C22_B02_005_416417.json : bloom1_date --> 2021-09-23
# C22_B02_005_416417.json : fr1_cnt --> 4
# C22_B02_007_416412.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_007_416412.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_007_416412.json : measured_date --> 2021-09-29
# C22_B02_007_416412.json : stem_length --> 38
# C22_B02_007_416412.json : leaf_cnt --> 7
# C22_B02_007_416412.json : leaf_width --> 8.5
# C22_B02_007_416412.json : leaf_length --> 11.4
# C22_B02_007_416412.json : stem_thick --> 12.3
# C22_B02_007_416412.json : bloom1_date --> 2021-08-25
# C22_B02_007_416412.json : bloom2_date --> 2021-09-23
# C22_B02_007_416412.json : fr1_cnt --> 4
# C22_B02_005_416410.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_005_416410.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_005_416410.json : measured_date --> 2021-09-29
# C22_B02_005_416410.json : stem_length --> 35.5
# C22_B02_005_416410.json : leaf_cnt --> 9
# C22_B02_005_416410.json : leaf_width --> 8
# C22_B02_005_416410.json : leaf_length --> 11.2
# C22_B02_005_416410.json : stem_thick --> 15.3
# C22_B02_005_416410.json : bloom1_date --> 2021-09-23
# C22_B02_005_416410.json : fr1_cnt --> 4
# C22_B02_007_416433.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_007_416433.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_007_416433.json : measured_date --> 2021-09-29
# C22_B02_007_416433.json : stem_length --> 38
# C22_B02_007_416433.json : leaf_cnt --> 7
# C22_B02_007_416433.json : leaf_width --> 8.5
# C22_B02_007_416433.json : leaf_length --> 11.4
# C22_B02_007_416433.json : stem_thick --> 12.3
# C22_B02_007_416433.json : bloom1_date --> 2021-08-25
# C22_B02_007_416433.json : bloom2_date --> 2021-09-23
# C22_B02_007_416433.json : fr1_cnt --> 4
# C22_B02_003_416436.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_003_416436.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_003_416436.json : measured_date --> 2021-09-29
# C22_B02_003_416436.json : stem_length --> 34
# C22_B02_003_416436.json : leaf_cnt --> 8
# C22_B02_003_416436.json : leaf_width --> 11.5
# C22_B02_003_416436.json : leaf_length --> 16.5
# C22_B02_003_416436.json : stem_thick --> 15.5
# C22_B02_003_416429.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_003_416429.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_003_416429.json : measured_date --> 2021-09-29
# C22_B02_003_416429.json : stem_length --> 34
# C22_B02_003_416429.json : leaf_cnt --> 8
# C22_B02_003_416429.json : leaf_width --> 11.5
# C22_B02_003_416429.json : leaf_length --> 16.5
# C22_B02_003_416429.json : stem_thick --> 15.5
# C22_B02_006_416425.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_006_416425.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_006_416425.json : measured_date --> 2021-09-29
# C22_B02_006_416425.json : stem_length --> 36
# C22_B02_006_416425.json : leaf_cnt --> 9
# C22_B02_006_416425.json : leaf_width --> 9
# C22_B02_006_416425.json : leaf_length --> 13.3
# C22_B02_006_416425.json : stem_thick --> 16.6
# C22_B02_007_416440.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_007_416440.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_007_416440.json : measured_date --> 2021-09-29
# C22_B02_007_416440.json : stem_length --> 38
# C22_B02_007_416440.json : leaf_cnt --> 7
# C22_B02_007_416440.json : leaf_width --> 8.5
# C22_B02_007_416440.json : leaf_length --> 11.4
# C22_B02_007_416440.json : stem_thick --> 12.3
# C22_B02_007_416440.json : bloom1_date --> 2021-08-25
# C22_B02_007_416440.json : bloom2_date --> 2021-09-23
# C22_B02_007_416440.json : fr1_cnt --> 4
# C22_B02_006_416439.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_006_416439.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_006_416439.json : measured_date --> 2021-09-29
# C22_B02_006_416439.json : stem_length --> 36
# C22_B02_006_416439.json : leaf_cnt --> 9
# C22_B02_006_416439.json : leaf_width --> 9
# C22_B02_006_416439.json : leaf_length --> 13.3
# C22_B02_006_416439.json : stem_thick --> 16.6
# C22_B02_005_416438.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_005_416438.json : dict_keys(['farm_id', 'receive_date', 'id', 'ti_value', 'hi_value', 'ci_value', 'ir_value', 'tl_value', 'ei_value', 'pl_value', 'sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value'])
# C22_B02_005_416438.json : measured_date --> 2021-09-29
# C22_B02_005_416438.json : stem_length --> 35.5
# C22_B02_005_416438.json : leaf_cnt --> 9
# C22_B02_005_416438.json : leaf_width --> 8
# C22_B02_005_416438.json : leaf_length --> 11.2
# C22_B02_005_416438.json : stem_thick --> 15.3
# C22_B02_005_416438.json : bloom1_date --> 2021-09-23
# C22_B02_005_416438.json : fr1_cnt --> 4

# %%
import pandas as pd

df = pd.DataFrame(df_data)
df
# Out:
#                     fname  image_id farm_id crops_id crops_type growth_stage  \
# 0      C24_B02_003_753155    753155  AIF005  C24_B02      딸기 금실          출뢰기
# 1      C24_B02_002_753133    753133  AIF005  C24_B02      딸기 금실          출뢰기
# 2      C24_B02_003_753134    753134  AIF005  C24_B02      딸기 금실          출뢰기
# 3      C24_B02_003_753162    753162  AIF005  C24_B02      딸기 금실          출뢰기
# 4      C24_B02_005_753144    753144  AIF005  C24_B02      딸기 금실          출뢰기
# ...                   ...       ...     ...      ...        ...          ...
# 24341  C22_B02_007_414673    414673  AIF005  C22_B02      딸기 금실          개화기
# 24342  C22_B02_005_414678    414678  AIF005  C22_B02      딸기 금실          출뢰기
# 24343  C22_B02_002_414674    414674  AIF005  C22_B02      딸기 금실          정식기
# 24344  C22_B02_001_414689    414689  AIF005  C22_B02      딸기 금실          정식기
# 24345  C22_B02_001_414696    414696  AIF005  C22_B02      딸기 금실          정식기
#
#            c_date    c_time  \
# 0      2022-01-08  15:15:16
# 1      2022-01-08  12:15:16
# 2      2022-01-08  12:15:16
# 3      2022-01-08  17:15:16
# 4      2022-01-08  14:15:16
# ...           ...       ...
# 24341  2021-08-29  06:46:51
# 24342  2021-08-29  07:46:51
# 24343  2021-08-29  07:46:51
# 24344  2021-08-29  09:46:51
# 24345  2021-08-29  10:46:51
#
#                                                     env1  \
# 0      {'farm_id': 'AIF005', 'receive_date': '2022-01...
# 1      {'farm_id': 'AIF005', 'receive_date': '2022-01...
# 2      {'farm_id': 'AIF005', 'receive_date': '2022-01...
# 3      {'farm_id': 'AIF005', 'receive_date': '2022-01...
# 4      {'farm_id': 'AIF005', 'receive_date': '2022-01...
# ...                                                  ...
# 24341  {'farm_id': 'AIF005', 'receive_date': '2021-08...
# 24342  {'farm_id': 'AIF005', 'receive_date': '2021-08...
# 24343  {'farm_id': 'AIF005', 'receive_date': '2021-08...
# 24344  {'farm_id': 'AIF005', 'receive_date': '2021-08...
# 24345  {'farm_id': 'AIF005', 'receive_date': '2021-08...
#
#                                                     env2  \
# 0      {'farm_id': 'AIF005', 'receive_date': '2022-01...
# 1      {'farm_id': 'AIF005', 'receive_date': '2022-01...
# 2      {'farm_id': 'AIF005', 'receive_date': '2022-01...
# 3      {'farm_id': 'AIF005', 'receive_date': '2022-01...
# 4      {'farm_id': 'AIF005', 'receive_date': '2022-01...
# ...                                                  ...
# 24341  {'farm_id': 'AIF005', 'receive_date': '2021-08...
# 24342  {'farm_id': 'AIF005', 'receive_date': '2021-08...
# 24343  {'farm_id': 'AIF005', 'receive_date': '2021-08...
# 24344  {'farm_id': 'AIF005', 'receive_date': '2021-08...
# 24345  {'farm_id': 'AIF005', 'receive_date': '2021-08...
#
#                                              growth_info  \
# 0      {'corps_id': 'C24_B02', 'measured_date': None,...
# 1      {'corps_id': 'C24_B02', 'measured_date': None,...
# 2      {'corps_id': 'C24_B02', 'measured_date': None,...
# 3      {'corps_id': 'C24_B02', 'measured_date': None,...
# 4      {'corps_id': 'C24_B02', 'measured_date': None,...
# ...                                                  ...
# 24341  {'corps_id': 'C22_B02', 'measured_date': None,...
# 24342  {'corps_id': 'C22_B02', 'measured_date': None,...
# 24343  {'corps_id': 'C22_B02', 'measured_date': None,...
# 24344  {'corps_id': 'C22_B02', 'measured_date': None,...
# 24345  {'corps_id': 'C22_B02', 'measured_date': None,...
#
#                                                 etc_info  img_width  \
# 0      {'corps_id': 'C24_B02', 'create_date': '', 'in...       1087
# 1      {'corps_id': 'C24_B02', 'create_date': '', 'in...       1121
# 2      {'corps_id': 'C24_B02', 'create_date': '', 'in...       1087
# 3      {'corps_id': 'C24_B02', 'create_date': '', 'in...       1087
# 4      {'corps_id': 'C24_B02', 'create_date': '', 'in...       1153
# ...                                                  ...        ...
# 24341  {'corps_id': 'C22_B02', 'create_date': '', 'in...       1419
# 24342  {'corps_id': 'C22_B02', 'create_date': '', 'in...       1286
# 24343  {'corps_id': 'C22_B02', 'create_date': '', 'in...       1389
# 24344  {'corps_id': 'C22_B02', 'create_date': '', 'in...       1511
# 24345  {'corps_id': 'C22_B02', 'create_date': '', 'in...       1511
#
#        img_height  bbox_num  \
# 0            1440        10
# 1            1441         2
# 2            1440        10
# 3            1440         6
# 4            1277         4
# ...           ...       ...
# 24341        1910        12
# 24342        1669         9
# 24343        2133         3
# 24344        2064         6
# 24345        2064         9
#
#                                              annotations  \
# 0      [{'segmentation': [656.78, 685.02, 704.33, 685...
# 1      [{'segmentation': [639.03, 524.27, 692.62, 524...
# 2      [{'segmentation': [655.86, 681.28, 708.9, 681....
# 3      [{'segmentation': [654.81, 685.55, 702.7, 685....
# 4      [{'segmentation': [316.88, 679.55, 527.79, 679...
# ...                                                  ...
# 24341  [{'segmentation': [1041.06, 439.31, 1367.39, 4...
# 24342  [{'segmentation': [583.91, 522.4, 769.33, 522....
# 24343  [{'segmentation': [408.28, 327.55, 728.42, 327...
# 24344  [{'segmentation': [20.75, 226.75, 428.42, 226....
# 24345  [{'segmentation': [652.4, 430.39, 874.04, 430....
#
#                                               categories
# 0      [{'id': 0, 'name': '화방', 'supercategory': 'non...
# 1      [{'id': 0, 'name': '줄기', 'supercategory': 'non...
# 2      [{'id': 0, 'name': '화방', 'supercategory': 'non...
# 3      [{'id': 0, 'name': '화방', 'supercategory': 'non...
# 4      [{'id': 0, 'name': '잎', 'supercategory': 'none...
# ...                                                  ...
# 24341  [{'id': 0, 'name': '잎', 'supercategory': 'none...
# 24342  [{'id': 0, 'name': '잎', 'supercategory': 'none...
# 24343  [{'id': 0, 'name': '잎', 'supercategory': 'none...
# 24344  [{'id': 0, 'name': '잎', 'supercategory': 'none...
# 24345  [{'id': 0, 'name': '잎', 'supercategory': 'none...
#
# [24346 rows x 17 columns]

# %%
df.to_csv("/content/drive/MyDrive/DLP/train_meta_data.csv", index=False)

# %%
annot_df = pd.DataFrame(annot_data)
annot_df
# Out:
#         image_id               fname  \
# 0         753155  C24_B02_003_753155
# 1         753155  C24_B02_003_753155
# 2         753155  C24_B02_003_753155
# 3         753155  C24_B02_003_753155
# 4         753155  C24_B02_003_753155
# ...          ...                 ...
# 173803    414696  C22_B02_001_414696
# 173804    414696  C22_B02_001_414696
# 173805    414696  C22_B02_001_414696
# 173806    414696  C22_B02_001_414696
# 173807    414696  C22_B02_001_414696
#
#                                                   segment      area  \
# 0       [656.78, 685.02, 704.33, 685.02, 704.33, 737.1...   2479.30
# 1       [758.65, 717.95, 837.32, 717.95, 837.32, 832.9...   9043.11
# 2       [806.23, 744.79, 878.19, 744.79, 878.19, 793.8...   3531.79
# 3       [804.4, 674.65, 896.49, 674.65, 896.49, 757.27...   7608.47
# 4       [708.02, 653.3, 754.36, 653.3, 754.36, 702.99,...   2302.63
# ...                                                   ...       ...
# 173803  [446.4, 419.87, 616.48, 419.87, 616.48, 533.04...  19247.95
# 173804  [567.86, 636.11, 725.11, 636.11, 725.11, 852.9...  34099.66
# 173805  [663.66, 749.66, 806.08, 749.66, 806.08, 1054....  43402.69
# 173806  [775.26, 609.44, 827.83, 609.44, 827.83, 1063....  23856.79
# 173807  [845.38, 570.94, 1021.4, 570.94, 1021.4, 639.6...  12101.37
#
#                                     bbox category
# 0         [656.78, 685.02, 47.56, 52.13]       화방
# 1        [758.65, 717.95, 78.67, 114.95]       과실
# 2         [806.23, 744.79, 71.96, 49.08]       과실
# 3          [804.4, 674.65, 92.09, 82.62]       과실
# 4          [708.02, 653.3, 46.34, 49.69]       화방
# ...                                  ...      ...
# 173803   [446.4, 419.87, 170.08, 113.17]       줄기
# 173804  [567.86, 636.11, 157.25, 216.85]       줄기
# 173805  [663.66, 749.66, 142.43, 304.73]       줄기
# 173806   [775.26, 609.44, 52.57, 453.81]       줄기
# 173807   [845.38, 570.94, 176.02, 68.75]       줄기
#
# [173808 rows x 6 columns]

# %%
annot_df.to_csv("/content/drive/MyDrive/DLP/train_annot_data.csv", index=False)

# %%
len(exinfo_json)
# Out:
# 3016

# %%
for json in exinfo_json:
    print(json)
    break
# Out:
# C25_B02_006_449700.json

# %%
exinfo_list = [x.split('.')[0] for x in exinfo_json]
len(exinfo_list), exinfo_list[0]
# Out:
# (3016, 'C25_B02_006_449700')

# %%
ex_df = df[df['fname'].isin(exinfo_list)]
ex_df
# Out:
#                     fname  image_id farm_id crops_id crops_type growth_stage  \
# 395    C24_B02_003_777478    777478  AIF005  C24_B02      딸기 금실          출뢰기
# 397    C22_B02_006_777468    777468  AIF005  C22_B02      딸기 금실          출뢰기
# 402    C25_B02_004_777459    777459  AIF005  C25_B02      딸기 금실        과실비대기
# 404    C24_B02_002_777477    777477  AIF005  C24_B02      딸기 금실          출뢰기
# 405    C22_B02_007_777469    777469  AIF005  C22_B02      딸기 금실          수확기
# ...                   ...       ...     ...      ...        ...          ...
# 23466  C22_B02_003_416429    416429  AIF005  C22_B02      딸기 금실          정식기
# 23467  C22_B02_006_416425    416425  AIF005  C22_B02      딸기 금실          정식기
# 23470  C22_B02_007_416440    416440  AIF005  C22_B02      딸기 금실          수확기
# 23471  C22_B02_006_416439    416439  AIF005  C22_B02      딸기 금실          정식기
# 23476  C22_B02_005_416438    416438  AIF005  C22_B02      딸기 금실        과실비대기
#
#            c_date    c_time  \
# 395    2022-01-12  08:15:16
# 397    2022-01-12  08:13:02
# 402    2022-01-12  07:44:31
# 404    2022-01-12  08:15:16
# 405    2022-01-12  08:13:02
# ...           ...       ...
# 23466  2021-09-29  17:19:03
# 23467  2021-09-29  17:16:08
# 23470  2021-09-29  17:31:56
# 23471  2021-09-29  17:31:56
# 23476  2021-09-29  17:31:56
#
#                                                     env1  \
# 395    {'farm_id': 'AIF005', 'receive_date': '2022-01...
# 397    {'farm_id': 'AIF005', 'receive_date': '2022-01...
# 402    {'farm_id': 'AIF005', 'receive_date': '2022-01...
# 404    {'farm_id': 'AIF005', 'receive_date': '2022-01...
# 405    {'farm_id': 'AIF005', 'receive_date': '2022-01...
# ...                                                  ...
# 23466  {'farm_id': 'AIF005', 'receive_date': '2021-09...
# 23467  {'farm_id': 'AIF005', 'receive_date': '2021-09...
# 23470  {'farm_id': 'AIF005', 'receive_date': '2021-09...
# 23471  {'farm_id': 'AIF005', 'receive_date': '2021-09...
# 23476  {'farm_id': 'AIF005', 'receive_date': '2021-09...
#
#                                                     env2  \
# 395    {'farm_id': 'AIF005', 'receive_date': '2022-01...
# 397    {'farm_id': 'AIF005', 'receive_date': '2022-01...
# 402    {'farm_id': 'AIF005', 'receive_date': '2022-01...
# 404    {'farm_id': 'AIF005', 'receive_date': '2022-01...
# 405    {'farm_id': 'AIF005', 'receive_date': '2022-01...
# ...                                                  ...
# 23466  {'farm_id': 'AIF005', 'receive_date': '2021-09...
# 23467  {'farm_id': 'AIF005', 'receive_date': '2021-09...
# 23470  {'farm_id': 'AIF005', 'receive_date': '2021-09...
# 23471  {'farm_id': 'AIF005', 'receive_date': '2021-09...
# 23476  {'farm_id': 'AIF005', 'receive_date': '2021-09...
#
#                                              growth_info  \
# 395    {'corps_id': 'C24_B02', 'measured_date': '2022...
# 397    {'corps_id': 'C22_B02', 'measured_date': '2022...
# 402    {'corps_id': 'C25_B02', 'measured_date': '2022...
# 404    {'corps_id': 'C24_B02', 'measured_date': '2022...
# 405    {'corps_id': 'C22_B02', 'measured_date': '2022...
# ...                                                  ...
# 23466  {'corps_id': 'C22_B02', 'measured_date': '2021...
# 23467  {'corps_id': 'C22_B02', 'measured_date': '2021...
# 23470  {'corps_id': 'C22_B02', 'measured_date': '2021...
# 23471  {'corps_id': 'C22_B02', 'measured_date': '2021...
# 23476  {'corps_id': 'C22_B02', 'measured_date': '2021...
#
#                                                 etc_info  img_width  \
# 395    {'corps_id': 'C24_B02', 'create_date': '', 'in...       1091
# 397    {'corps_id': 'C22_B02', 'create_date': '', 'in...       1001
# 402    {'corps_id': 'C25_B02', 'create_date': '', 'in...       1065
# 404    {'corps_id': 'C24_B02', 'create_date': '', 'in...        949
# 405    {'corps_id': 'C22_B02', 'create_date': '', 'in...        958
# ...                                                  ...        ...
# 23466  {'corps_id': 'C22_B02', 'create_date': '', 'in...       1419
# 23467  {'corps_id': 'C22_B02', 'create_date': '', 'in...       1243
# 23470  {'corps_id': 'C22_B02', 'create_date': '', 'in...       1290
# 23471  {'corps_id': 'C22_B02', 'create_date': '', 'in...       1299
# 23476  {'corps_id': 'C22_B02', 'create_date': '', 'in...       1274
#
#        img_height  bbox_num  \
# 395          1445        14
# 397          1334         9
# 402          1559         4
# 404          1447         4
# 405          1280         5
# ...           ...       ...
# 23466        1766         8
# 23467        1783         7
# 23470        1875         9
# 23471        1692         8
# 23476        1578         9
#
#                                              annotations  \
# 395    [{'segmentation': [902.19, 693.7, 988.81, 693....
# 397    [{'segmentation': [497.67, 581.59, 530.36, 581...
# 402    [{'segmentation': [452.27, 886.05, 556.2, 886....
# 404    [{'segmentation': [307.54, 457.32, 383.54, 457...
# 405    [{'segmentation': [647.46, 686.95, 821.68, 686...
# ...                                                  ...
# 23466  [{'segmentation': [35.07, 340.35, 199.45, 340....
# 23467  [{'segmentation': [604.92, 662.13, 860.11, 662...
# 23470  [{'segmentation': [376.39, 447.79, 700.37, 447...
# 23471  [{'segmentation': [521.13, 634.72, 770.06, 634...
# 23476  [{'segmentation': [489.05, 409.76, 874.5, 409....
#
#                                               categories
# 395    [{'id': 0, 'name': '잎', 'supercategory': 'none...
# 397    [{'id': 0, 'name': '줄기', 'supercategory': 'non...
# 402    [{'id': 0, 'name': '과실', 'supercategory': 'non...
# 404    [{'id': 0, 'name': '줄기', 'supercategory': 'non...
# 405    [{'id': 0, 'name': '잎', 'supercategory': 'none...
# ...                                                  ...
# 23466  [{'id': 0, 'name': '잎', 'supercategory': 'none...
# 23467  [{'id': 0, 'name': '잎', 'supercategory': 'none...
# 23470  [{'id': 0, 'name': '잎', 'supercategory': 'none...
# 23471  [{'id': 0, 'name': '잎', 'supercategory': 'none...
# 23476  [{'id': 0, 'name': '잎', 'supercategory': 'none...
#
# [3016 rows x 17 columns]

# %%
ex_df.to_csv("/content/drive/MyDrive/DLP/train_ex_data.csv", index=False)

# %%
json_data_dir = "/content/drive/MyDrive/DLP/label_data_json/extracted_valid"

json_list = os.listdir(json_data_dir)
json_list[:10], len(json_list)
# Out:
# (['C25_B02_003_423515.json',
#   'C24_B02_005_455867.json',
#   'C24_B02_005_455902.json',
#   'C24_B02_005_455944.json',
#   'C24_B02_005_455965.json',
#   'C24_B02_005_456103.json',
#   'C24_B02_005_456131.json',
#   'C24_B02_005_456173.json',
#   'C24_B02_005_456290.json',
#   'C24_B02_005_456732.json'],
#  3025)

# %%
import json

df_data = dict(
    fname=[], image_id=[], farm_id=[], crops_id=[],
    crops_type=[], growth_stage=[], c_date=[], c_time=[],
    env1=[], env2=[], growth_info=[], etc_info=[],
    img_width=[], img_height=[], bbox_num=[], annotations=[], categories=[]
)
annot_data = dict(
    image_id=[], fname=[],
    segment=[], area=[], bbox=[], category=[]
)
exinfo_json = set()

for jname in tqdm(json_list, desc='Processing'):
    with open(os.path.join(json_data_dir, jname), 'r') as f:
        data = json.load(f)

    f_name = jname.split('.')[0]
    df_data['fname'].append(f_name)
    val = data['images']['image_id']
    df_data['image_id'].append(val if val else None)
    val = data['images']['farm_id']
    df_data['farm_id'].append(val if val else None)
    val = data['images']['crops_id']
    df_data['crops_id'].append(val if val else None)
    val = datetime.strptime(data['images']['date_captured'], "%Y-%m-%d %H:%M:%S")
    df_data['c_date'].append(val.date() if val else None)
    df_data['c_time'].append(val.time() if val else None)
    val = data['images']['crops'] +" "+ data['images']['kind_type']
    df_data['crops_type'].append(val if val else None)
    val = data['images']['growth_stage']
    df_data['growth_stage'].append(val if val else None)
    val = data['envrionments'][0]
    if len(val) > 10:
        exinfo_json.add(f_name)
        print(f"{jname} : {list(val.keys())[10:]}")
    df_data['env1'].append(val if val else None)
    val = data['envrionments'][1]
    if len(val) > 10:
        exinfo_json.add(f_name)
        print(f"{jname} : {list(val.keys())[10:]}")
    df_data['env2'].append(val if val else None)
    val = data['growth_index']
    df_data['growth_info'].append(val if val else None)
    for i, (k, v) in enumerate(val.items()):
        if i==0: continue
        if v:
            exinfo_json.add(f_name)
            print(f"{jname} : {k} --> {v}")
    val = data['etc_infor']
    df_data['etc_info'].append(val if val else None)
    for i, (k, v) in enumerate(val.items()):
        if i==0: continue
        if v:
            exinfo_json.add(f_name)
            print(f"{jname} : {k} --> {v}")
    val = int(data['images']['width'])
    df_data['img_width'].append(val if val else None)
    val = int(data['images']['height'])
    df_data['img_height'].append(val if val else None)
    anno = data['annotations']
    cate = data['categories']
    df_data['bbox_num'].append(len(anno))
    df_data['annotations'].append(anno)
    df_data['categories'].append(cate)
    for a, c in zip(anno, cate):
        annot_data['image_id'].append(a['image_id'])
        annot_data['fname'].append(f_name)
        annot_data['segment'].append(a['segmentation'])
        annot_data['area'].append(a['area'])
        annot_data['bbox'].append(a['bbox'])
        annot_data['category'].append(c['name'])
# Out:
# Processing:   0%|          | 0/3025 [00:00<?, ?it/s]
# C24_B02_005_457647.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_457647.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_457647.json : measured_date --> 2021-09-08
# C24_B02_005_457647.json : stem_length --> 40.5
# C24_B02_005_457647.json : leaf_cnt --> 8
# C24_B02_005_457647.json : leaf_width --> 7.5
# C24_B02_005_457647.json : leaf_length --> 10.6
# C24_B02_005_457647.json : stem_thick --> 11.5
# C24_B02_005_457682.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_457682.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_457682.json : measured_date --> 2021-09-08
# C24_B02_005_457682.json : stem_length --> 40.5
# C24_B02_005_457682.json : leaf_cnt --> 8
# C24_B02_005_457682.json : leaf_width --> 7.5
# C24_B02_005_457682.json : leaf_length --> 10.6
# C24_B02_005_457682.json : stem_thick --> 11.5
# C24_B02_005_457703.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_457703.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_457703.json : measured_date --> 2021-09-08
# C24_B02_005_457703.json : stem_length --> 40.5
# C24_B02_005_457703.json : leaf_cnt --> 8
# C24_B02_005_457703.json : leaf_width --> 7.5
# C24_B02_005_457703.json : leaf_length --> 10.6
# C24_B02_005_457703.json : stem_thick --> 11.5
# C24_B02_005_457846.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_457846.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_457846.json : measured_date --> 2021-09-15
# C24_B02_005_457846.json : stem_length --> 40.9
# C24_B02_005_457846.json : leaf_cnt --> 9
# C24_B02_005_457846.json : leaf_width --> 8.1
# C24_B02_005_457846.json : leaf_length --> 11.2
# C24_B02_005_457846.json : stem_thick --> 11.8
# C24_B02_005_457871.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_457871.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_457871.json : measured_date --> 2021-09-15
# C24_B02_005_457871.json : stem_length --> 40.9
# C24_B02_005_457871.json : leaf_cnt --> 9
# C24_B02_005_457871.json : leaf_width --> 8.1
# C24_B02_005_457871.json : leaf_length --> 11.2
# C24_B02_005_457871.json : stem_thick --> 11.8
# C24_B02_005_457892.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_457892.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_457892.json : measured_date --> 2021-09-15
# C24_B02_005_457892.json : stem_length --> 40.9
# C24_B02_005_457892.json : leaf_cnt --> 9
# C24_B02_005_457892.json : leaf_width --> 8.1
# C24_B02_005_457892.json : leaf_length --> 11.2
# C24_B02_005_457892.json : stem_thick --> 11.8
# C24_B02_005_458677.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_458677.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_458677.json : measured_date --> 2021-09-23
# C24_B02_005_458677.json : stem_length --> 37.8
# C24_B02_005_458677.json : leaf_cnt --> 11
# C24_B02_005_458677.json : leaf_width --> 8.1
# C24_B02_005_458677.json : leaf_length --> 12.2
# C24_B02_005_458677.json : stem_thick --> 12.1
# C24_B02_005_459344.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_459344.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_459344.json : measured_date --> 2021-09-29
# C24_B02_005_459344.json : stem_length --> 30.5
# C24_B02_005_459344.json : leaf_cnt --> 8
# C24_B02_005_459344.json : leaf_width --> 8.6
# C24_B02_005_459344.json : leaf_length --> 13.2
# C24_B02_005_459344.json : stem_thick --> 13.3
# C24_B02_005_459344.json : bloom1_date --> 2021-09-29
# C24_B02_005_459344.json : fr1_cnt --> 1
# C24_B02_005_507981.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_507981.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_507981.json : measured_date --> 2021-11-17
# C24_B02_005_507981.json : stem_length --> 29.1
# C24_B02_005_507981.json : leaf_cnt --> 9
# C24_B02_005_507981.json : leaf_width --> 7
# C24_B02_005_507981.json : leaf_length --> 11.2
# C24_B02_005_507981.json : stem_thick --> 15.8
# C24_B02_005_507981.json : bloom1_date --> 2021-09-29
# C24_B02_005_507981.json : bloom2_date --> 2021-11-10
# C24_B02_005_507981.json : fr1_cnt --> 2
# C24_B02_005_507981.json : fr_weight --> 19
# C24_B02_005_573845.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_573845.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_573845.json : measured_date --> 2021-12-01
# C24_B02_005_573845.json : stem_length --> 29.2
# C24_B02_005_573845.json : leaf_cnt --> 9
# C24_B02_005_573845.json : leaf_width --> 8.7
# C24_B02_005_573845.json : leaf_length --> 13.5
# C24_B02_005_573845.json : stem_thick --> 17.1
# C24_B02_005_573845.json : bloom1_date --> 2021-09-29
# C24_B02_005_573845.json : bloom2_date --> 2021-11-10
# C24_B02_005_573845.json : fr2_cnt --> 3
# C24_B02_005_573845.json : fr_weight --> 22
# C24_B02_005_594654.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_594654.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_594654.json : measured_date --> 2021-12-08
# C24_B02_005_594654.json : stem_length --> 28.4
# C24_B02_005_594654.json : leaf_cnt --> 10
# C24_B02_005_594654.json : leaf_width --> 8.8
# C24_B02_005_594654.json : leaf_length --> 13.7
# C24_B02_005_594654.json : stem_thick --> 17.4
# C24_B02_005_594654.json : bloom1_date --> 2021-09-29
# C24_B02_005_594654.json : bloom2_date --> 2021-11-10
# C24_B02_005_594654.json : fr2_cnt --> 5
# C24_B02_005_594654.json : fr_weight --> 22
# C24_B02_005_606180.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_606180.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_606180.json : measured_date --> 2021-12-08
# C24_B02_005_606180.json : stem_length --> 28.4
# C24_B02_005_606180.json : leaf_cnt --> 10
# C24_B02_005_606180.json : leaf_width --> 8.8
# C24_B02_005_606180.json : leaf_length --> 13.7
# C24_B02_005_606180.json : stem_thick --> 17.4
# C24_B02_005_606180.json : bloom1_date --> 2021-09-29
# C24_B02_005_606180.json : bloom2_date --> 2021-11-10
# C24_B02_005_606180.json : fr2_cnt --> 5
# C24_B02_005_606180.json : fr_weight --> 22
# C24_B02_005_606192.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_606192.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_606192.json : measured_date --> 2021-12-08
# C24_B02_005_606192.json : stem_length --> 28.4
# C24_B02_005_606192.json : leaf_cnt --> 10
# C24_B02_005_606192.json : leaf_width --> 8.8
# C24_B02_005_606192.json : leaf_length --> 13.7
# C24_B02_005_606192.json : stem_thick --> 17.4
# C24_B02_005_606192.json : bloom1_date --> 2021-09-29
# C24_B02_005_606192.json : bloom2_date --> 2021-11-10
# C24_B02_005_606192.json : fr2_cnt --> 5
# C24_B02_005_606192.json : fr_weight --> 22
# C24_B02_005_621924.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_621924.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_621924.json : measured_date --> 2021-12-15
# C24_B02_005_621924.json : stem_length --> 22.5
# C24_B02_005_621924.json : leaf_cnt --> 6
# C24_B02_005_621924.json : leaf_width --> 7.1
# C24_B02_005_621924.json : leaf_length --> 11.9
# C24_B02_005_621924.json : stem_thick --> 14
# C24_B02_005_621924.json : bloom1_date --> 2021-09-29
# C24_B02_005_621924.json : bloom2_date --> 2021-11-10
# C24_B02_005_621924.json : fr2_cnt --> 3
# C24_B02_005_648449.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_648449.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_648449.json : measured_date --> 2021-12-22
# C24_B02_005_648449.json : stem_length --> 22.5
# C24_B02_005_648449.json : leaf_cnt --> 6
# C24_B02_005_648449.json : leaf_width --> 7.3
# C24_B02_005_648449.json : leaf_length --> 11.7
# C24_B02_005_648449.json : stem_thick --> 16.7
# C24_B02_005_648449.json : bloom1_date --> 2021-09-29
# C24_B02_005_648449.json : bloom2_date --> 2021-11-10
# C24_B02_005_648449.json : fr2_cnt --> 2
# C24_B02_005_648449.json : fr_weight --> 13
# C24_B02_005_703585.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_703585.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_703585.json : measured_date --> 2021-12-29
# C24_B02_005_703585.json : stem_length --> 22.5
# C24_B02_005_703585.json : leaf_cnt --> 7
# C24_B02_005_703585.json : leaf_width --> 7.2
# C24_B02_005_703585.json : leaf_length --> 11.6
# C24_B02_005_703585.json : stem_thick --> 17.7
# C24_B02_005_703585.json : bloom1_date --> 2021-09-29
# C24_B02_005_703585.json : bloom2_date --> 2021-11-10
# C24_B02_005_703585.json : fr2_cnt --> 2
# C24_B02_005_703585.json : fr_weight --> 11
# C24_B02_005_703627.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_703627.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_703627.json : measured_date --> 2021-12-29
# C24_B02_005_703627.json : stem_length --> 22.5
# C24_B02_005_703627.json : leaf_cnt --> 7
# C24_B02_005_703627.json : leaf_width --> 7.2
# C24_B02_005_703627.json : leaf_length --> 11.6
# C24_B02_005_703627.json : stem_thick --> 17.7
# C24_B02_005_703627.json : bloom1_date --> 2021-09-29
# C24_B02_005_703627.json : bloom2_date --> 2021-11-10
# C24_B02_005_703627.json : fr2_cnt --> 2
# C24_B02_005_703627.json : fr_weight --> 11
# C24_B02_005_777474.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_777474.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_777474.json : measured_date --> 2022-01-12
# C24_B02_005_777474.json : stem_length --> 23.2
# C24_B02_005_777474.json : leaf_cnt --> 7
# C24_B02_005_777474.json : leaf_width --> 7.2
# C24_B02_005_777474.json : leaf_length --> 11.8
# C24_B02_005_777474.json : stem_thick --> 12.6
# C24_B02_005_777474.json : bloom1_date --> 2021-09-29
# C24_B02_005_777474.json : bloom2_date --> 2021-11-10
# C24_B02_006_425200.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_006_425200.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_006_425200.json : measured_date --> 2021-10-13
# C24_B02_006_425200.json : stem_length --> 31
# C24_B02_006_425200.json : leaf_cnt --> 10
# C24_B02_006_425200.json : leaf_width --> 9.7
# C24_B02_006_425200.json : leaf_length --> 14.4
# C24_B02_006_425200.json : stem_thick --> 13.8
# C24_B02_006_425200.json : bloom1_date --> 2021-09-29
# C24_B02_006_425200.json : fr1_cnt --> 4
# C24_B02_006_425200.json : fr_weight --> 11
# C24_B02_006_425255.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_006_425255.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_006_425255.json : measured_date --> 2021-10-13
# C24_B02_006_425255.json : stem_length --> 31
# C24_B02_006_425255.json : leaf_cnt --> 10
# C24_B02_006_425255.json : leaf_width --> 9.7
# C24_B02_006_425255.json : leaf_length --> 14.4
# C24_B02_006_425255.json : stem_thick --> 13.8
# C24_B02_006_425255.json : bloom1_date --> 2021-09-29
# C24_B02_006_425255.json : fr1_cnt --> 4
# C24_B02_006_425255.json : fr_weight --> 11
# C24_B02_006_456426.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_006_456426.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_006_456426.json : measured_date --> 2021-09-01
# C24_B02_006_456426.json : stem_length --> 35.3
# C24_B02_006_456426.json : leaf_cnt --> 5
# C24_B02_006_456426.json : leaf_width --> 6.7
# C24_B02_006_456426.json : leaf_length --> 9
# C24_B02_006_456426.json : stem_thick --> 12.5
# C24_B02_006_457662.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_006_457662.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_006_457662.json : measured_date --> 2021-09-08
# C24_B02_006_457662.json : stem_length --> 35.5
# C24_B02_006_457662.json : leaf_cnt --> 6
# C24_B02_006_457662.json : leaf_width --> 6.8
# C24_B02_006_457662.json : leaf_length --> 9.5
# C24_B02_006_457662.json : stem_thick --> 13
# C24_B02_006_457676.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_006_457676.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_006_457676.json : measured_date --> 2021-09-08
# C24_B02_006_457676.json : stem_length --> 35.5
# C24_B02_006_457676.json : leaf_cnt --> 6
# C24_B02_006_457676.json : leaf_width --> 6.8
# C24_B02_006_457676.json : leaf_length --> 9.5
# C24_B02_006_457676.json : stem_thick --> 13
# C24_B02_006_460597.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_006_460597.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_006_460597.json : measured_date --> 2021-11-10
# C24_B02_006_460597.json : stem_length --> 31.2
# C24_B02_006_460597.json : leaf_cnt --> 11
# C24_B02_006_460597.json : leaf_width --> 8.1
# C24_B02_006_460597.json : leaf_length --> 11.3
# C24_B02_006_460597.json : stem_thick --> 16.5
# C24_B02_006_460597.json : bloom1_date --> 2021-09-29
# C24_B02_006_460597.json : fr1_cnt --> 3
# C24_B02_006_507964.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_006_507964.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_006_507964.json : measured_date --> 2021-11-17
# C24_B02_006_507964.json : stem_length --> 31.7
# C24_B02_006_507964.json : leaf_cnt --> 11
# C24_B02_006_507964.json : leaf_width --> 10
# C24_B02_006_507964.json : leaf_length --> 14.8
# C24_B02_006_507964.json : stem_thick --> 15.4
# C24_B02_006_507964.json : bloom1_date --> 2021-09-29
# C24_B02_006_507964.json : fr1_cnt --> 2
# C24_B02_006_507964.json : fr_weight --> 4
# C24_B02_006_573842.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_006_573842.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_006_573842.json : measured_date --> 2021-12-01
# C24_B02_006_573842.json : stem_length --> 29.3
# C24_B02_006_573842.json : leaf_cnt --> 12
# C24_B02_006_573842.json : leaf_width --> 7.5
# C24_B02_006_573842.json : leaf_length --> 9.8
# C24_B02_006_573842.json : stem_thick --> 15.1
# C24_B02_006_573842.json : bloom1_date --> 2021-09-29
# C24_B02_006_606208.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_006_606208.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_006_606208.json : measured_date --> 2021-12-08
# C24_B02_006_606208.json : stem_length --> 30.3
# C24_B02_006_606208.json : leaf_cnt --> 11
# C24_B02_006_606208.json : leaf_width --> 10
# C24_B02_006_606208.json : leaf_length --> 12.4
# C24_B02_006_606208.json : stem_thick --> 16
# C24_B02_006_606208.json : bloom1_date --> 2021-09-29
# C24_B02_006_606208.json : bloom2_date --> 2021-12-08
# C24_B02_006_621896.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_006_621896.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_006_621896.json : measured_date --> 2021-12-15
# C24_B02_006_621896.json : stem_length --> 17
# C24_B02_006_621896.json : leaf_cnt --> 9
# C24_B02_006_621896.json : leaf_width --> 7.6
# C24_B02_006_621896.json : leaf_length --> 10.3
# C24_B02_006_621896.json : stem_thick --> 16.7
# C24_B02_006_621896.json : bloom1_date --> 2021-09-29
# C24_B02_006_621896.json : bloom2_date --> 2021-12-08
# C24_B02_006_621896.json : fr2_cnt --> 1
# C24_B02_006_703604.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_006_703604.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_006_703604.json : measured_date --> 2021-12-29
# C24_B02_006_703604.json : stem_length --> 18
# C24_B02_006_703604.json : leaf_cnt --> 8
# C24_B02_006_703604.json : leaf_width --> 7.7
# C24_B02_006_703604.json : leaf_length --> 10.3
# C24_B02_006_703604.json : stem_thick --> 16.5
# C24_B02_006_703604.json : bloom1_date --> 2021-09-29
# C24_B02_006_703604.json : bloom2_date --> 2021-12-08
# C24_B02_006_703604.json : fr2_cnt --> 5
# C24_B02_006_739090.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_006_739090.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_006_739090.json : measured_date --> 2022-01-05
# C24_B02_006_739090.json : stem_length --> 23.4
# C24_B02_006_739090.json : leaf_cnt --> 8
# C24_B02_006_739090.json : leaf_width --> 7.6
# C24_B02_006_739090.json : leaf_length --> 10.2
# C24_B02_006_739090.json : stem_thick --> 17.7
# C24_B02_006_739090.json : bloom1_date --> 2021-09-29
# C24_B02_006_739090.json : bloom2_date --> 2021-12-08
# C24_B02_006_739090.json : bloom3_date --> 2021-12-09
# C24_B02_006_739090.json : fr2_cnt --> 5
# C24_B02_006_739097.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_006_739097.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_006_739097.json : measured_date --> 2022-01-05
# C24_B02_006_739097.json : stem_length --> 23.4
# C24_B02_006_739097.json : leaf_cnt --> 8
# C24_B02_006_739097.json : leaf_width --> 7.6
# C24_B02_006_739097.json : leaf_length --> 10.2
# C24_B02_006_739097.json : stem_thick --> 17.7
# C24_B02_006_739097.json : bloom1_date --> 2021-09-29
# C24_B02_006_739097.json : bloom2_date --> 2021-12-08
# C24_B02_006_739097.json : bloom3_date --> 2021-12-09
# C24_B02_006_739097.json : fr2_cnt --> 5
# C25_B02_001_446699.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_001_446699.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_001_446699.json : measured_date --> 2021-09-01
# C25_B02_001_446699.json : stem_length --> 43.5
# C25_B02_001_446699.json : leaf_cnt --> 6
# C25_B02_001_446699.json : leaf_width --> 8.2
# C25_B02_001_446699.json : leaf_length --> 10.8
# C25_B02_001_446699.json : stem_thick --> 12.1
# C25_B02_001_446727.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_001_446727.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_001_446727.json : measured_date --> 2021-09-01
# C25_B02_001_446727.json : stem_length --> 43.5
# C25_B02_001_446727.json : leaf_cnt --> 6
# C25_B02_001_446727.json : leaf_width --> 8.2
# C25_B02_001_446727.json : leaf_length --> 10.8
# C25_B02_001_446727.json : stem_thick --> 12.1
# C25_B02_001_446803.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_001_446803.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_001_446803.json : measured_date --> 2021-09-01
# C25_B02_001_446803.json : stem_length --> 43.5
# C25_B02_001_446803.json : leaf_cnt --> 6
# C25_B02_001_446803.json : leaf_width --> 8.2
# C25_B02_001_446803.json : leaf_length --> 10.8
# C25_B02_001_446803.json : stem_thick --> 12.1
# C25_B02_001_450293.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_001_450293.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_001_450293.json : measured_date --> 2021-09-15
# C25_B02_001_450293.json : stem_length --> 43.5
# C25_B02_001_450293.json : leaf_cnt --> 7
# C25_B02_001_450293.json : leaf_width --> 8.7
# C25_B02_001_450293.json : leaf_length --> 11.5
# C25_B02_001_450293.json : stem_thick --> 13.5
# C25_B02_001_450343.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_001_450343.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_001_450343.json : measured_date --> 2021-09-15
# C25_B02_001_450343.json : stem_length --> 43.5
# C25_B02_001_450343.json : leaf_cnt --> 7
# C25_B02_001_450343.json : leaf_width --> 8.7
# C25_B02_001_450343.json : leaf_length --> 11.5
# C25_B02_001_450343.json : stem_thick --> 13.5
# C25_B02_001_507920.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_001_507920.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_001_507920.json : measured_date --> 2021-11-17
# C25_B02_001_507920.json : stem_length --> 31
# C25_B02_001_507920.json : leaf_cnt --> 18
# C25_B02_001_507920.json : leaf_width --> 9.1
# C25_B02_001_507920.json : leaf_length --> 12.1
# C25_B02_001_507920.json : stem_thick --> 16.7
# C25_B02_001_507920.json : bloom1_date --> 2021-11-03
# C25_B02_001_507920.json : fr1_cnt --> 5
# C25_B02_001_507928.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_001_507928.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_001_507928.json : measured_date --> 2021-11-17
# C25_B02_001_507928.json : stem_length --> 31
# C25_B02_001_507928.json : leaf_cnt --> 18
# C25_B02_001_507928.json : leaf_width --> 9.1
# C25_B02_001_507928.json : leaf_length --> 12.1
# C25_B02_001_507928.json : stem_thick --> 16.7
# C25_B02_001_507928.json : bloom1_date --> 2021-11-03
# C25_B02_001_507928.json : fr1_cnt --> 5
# C25_B02_001_509350.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_001_509350.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_001_509350.json : measured_date --> 2021-11-17
# C25_B02_001_509350.json : stem_length --> 31
# C25_B02_001_509350.json : leaf_cnt --> 18
# C25_B02_001_509350.json : leaf_width --> 9.1
# C25_B02_001_509350.json : leaf_length --> 12.1
# C25_B02_001_509350.json : stem_thick --> 16.7
# C25_B02_001_509350.json : bloom1_date --> 2021-11-03
# C25_B02_001_509350.json : fr1_cnt --> 5
# C25_B02_001_601208.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_001_601208.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_001_601208.json : measured_date --> 2021-12-08
# C25_B02_001_601208.json : stem_length --> 30.1
# C25_B02_001_601208.json : leaf_cnt --> 14
# C25_B02_001_601208.json : leaf_width --> 8.2
# C25_B02_001_601208.json : leaf_length --> 11.5
# C25_B02_001_601208.json : stem_thick --> 18.3
# C25_B02_001_601208.json : bloom1_date --> 2021-11-03
# C25_B02_001_601208.json : fr1_cnt --> 5
# C25_B02_001_601208.json : fr_weight --> 35
# C25_B02_001_648363.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_001_648363.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_001_648363.json : measured_date --> 2021-12-22
# C25_B02_001_648363.json : stem_length --> 30
# C25_B02_001_648363.json : leaf_cnt --> 12
# C25_B02_001_648363.json : leaf_width --> 9.2
# C25_B02_001_648363.json : leaf_length --> 12.9
# C25_B02_001_648363.json : stem_thick --> 18.6
# C25_B02_001_648363.json : bloom1_date --> 2021-11-03
# C25_B02_001_648363.json : fr_weight --> 24
# C25_B02_001_670621.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_001_670621.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_001_670621.json : measured_date --> 2021-12-22
# C25_B02_001_670621.json : stem_length --> 30
# C25_B02_001_670621.json : leaf_cnt --> 12
# C25_B02_001_670621.json : leaf_width --> 9.2
# C25_B02_001_670621.json : leaf_length --> 12.9
# C25_B02_001_670621.json : stem_thick --> 18.6
# C25_B02_001_670621.json : bloom1_date --> 2021-11-03
# C25_B02_001_670621.json : fr_weight --> 24
# C25_B02_002_422505.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_422505.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_422505.json : measured_date --> 2021-10-13
# C25_B02_002_422505.json : stem_length --> 25.5
# C25_B02_002_422505.json : leaf_cnt --> 7
# C25_B02_002_422505.json : leaf_width --> 8.4
# C25_B02_002_422505.json : leaf_length --> 11.3
# C25_B02_002_422505.json : stem_thick --> 14.5
# C25_B02_002_422505.json : bloom1_date --> 2021-09-29
# C25_B02_002_422505.json : fr1_cnt --> 9
# C25_B02_002_422505.json : fr_weight --> 30
# C25_B02_002_422521.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_422521.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_422521.json : measured_date --> 2021-10-13
# C25_B02_002_422521.json : stem_length --> 25.5
# C25_B02_002_422521.json : leaf_cnt --> 7
# C25_B02_002_422521.json : leaf_width --> 8.4
# C25_B02_002_422521.json : leaf_length --> 11.3
# C25_B02_002_422521.json : stem_thick --> 14.5
# C25_B02_002_422521.json : bloom1_date --> 2021-09-29
# C25_B02_002_422521.json : fr1_cnt --> 9
# C25_B02_002_422521.json : fr_weight --> 30
# C25_B02_002_423372.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_423372.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_423372.json : measured_date --> 2021-10-27
# C25_B02_002_423372.json : stem_length --> 25.3
# C25_B02_002_423372.json : leaf_cnt --> 9
# C25_B02_002_423372.json : leaf_width --> 8
# C25_B02_002_423372.json : leaf_length --> 11.8
# C25_B02_002_423372.json : stem_thick --> 13.4
# C25_B02_002_423372.json : bloom1_date --> 2021-09-29
# C25_B02_002_423372.json : fr1_cnt --> 5
# C25_B02_002_423372.json : fr_weight --> 18
# C25_B02_002_423412.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_423412.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_423412.json : measured_date --> 2021-10-27
# C25_B02_002_423412.json : stem_length --> 25.3
# C25_B02_002_423412.json : leaf_cnt --> 9
# C25_B02_002_423412.json : leaf_width --> 8
# C25_B02_002_423412.json : leaf_length --> 11.8
# C25_B02_002_423412.json : stem_thick --> 13.4
# C25_B02_002_423412.json : bloom1_date --> 2021-09-29
# C25_B02_002_423412.json : fr1_cnt --> 5
# C25_B02_002_423412.json : fr_weight --> 18
# C25_B02_002_424225.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_424225.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_424225.json : measured_date --> 2021-11-03
# C25_B02_002_424225.json : stem_length --> 25.5
# C25_B02_002_424225.json : leaf_cnt --> 10
# C25_B02_002_424225.json : leaf_width --> 7.8
# C25_B02_002_424225.json : leaf_length --> 11
# C25_B02_002_424225.json : stem_thick --> 13
# C25_B02_002_424225.json : bloom1_date --> 2021-09-29
# C25_B02_002_424225.json : fr1_cnt --> 2
# C25_B02_002_424233.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_424233.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_424233.json : measured_date --> 2021-11-03
# C25_B02_002_424233.json : stem_length --> 25.5
# C25_B02_002_424233.json : leaf_cnt --> 10
# C25_B02_002_424233.json : leaf_width --> 7.8
# C25_B02_002_424233.json : leaf_length --> 11
# C25_B02_002_424233.json : stem_thick --> 13
# C25_B02_002_424233.json : bloom1_date --> 2021-09-29
# C25_B02_002_424233.json : fr1_cnt --> 2
# C25_B02_002_450342.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_450342.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_450342.json : measured_date --> 2021-09-15
# C25_B02_002_450342.json : stem_length --> 37
# C25_B02_002_450342.json : leaf_cnt --> 6
# C25_B02_002_450342.json : leaf_width --> 8
# C25_B02_002_450342.json : leaf_length --> 10.5
# C25_B02_002_450342.json : stem_thick --> 14.2
# C25_B02_002_452010.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_452010.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_452010.json : measured_date --> 2021-09-23
# C25_B02_002_452010.json : stem_length --> 25
# C25_B02_002_452010.json : leaf_cnt --> 5
# C25_B02_002_452010.json : leaf_width --> 7.4
# C25_B02_002_452010.json : leaf_length --> 10.3
# C25_B02_002_452010.json : stem_thick --> 14.3
# C25_B02_002_452214.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_452214.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_452214.json : measured_date --> 2021-09-23
# C25_B02_002_452214.json : stem_length --> 25
# C25_B02_002_452214.json : leaf_cnt --> 5
# C25_B02_002_452214.json : leaf_width --> 7.4
# C25_B02_002_452214.json : leaf_length --> 10.3
# C25_B02_002_452214.json : stem_thick --> 14.3
# C25_B02_002_454219.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_454219.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_454219.json : measured_date --> 2021-09-29
# C25_B02_002_454219.json : stem_length --> 37
# C25_B02_002_454219.json : leaf_cnt --> 5
# C25_B02_002_454219.json : leaf_width --> 8.2
# C25_B02_002_454219.json : leaf_length --> 21.2
# C25_B02_002_454219.json : stem_thick --> 16.8
# C25_B02_002_454219.json : bloom1_date --> 2021-09-29
# C25_B02_002_454219.json : fr1_cnt --> 1
# C25_B02_002_454233.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_454233.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_454233.json : measured_date --> 2021-09-29
# C25_B02_002_454233.json : stem_length --> 37
# C25_B02_002_454233.json : leaf_cnt --> 5
# C25_B02_002_454233.json : leaf_width --> 8.2
# C25_B02_002_454233.json : leaf_length --> 21.2
# C25_B02_002_454233.json : stem_thick --> 16.8
# C25_B02_002_454233.json : bloom1_date --> 2021-09-29
# C25_B02_002_454233.json : fr1_cnt --> 1
# C25_B02_002_500860.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_500860.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_500860.json : measured_date --> 2021-11-17
# C25_B02_002_500860.json : stem_length --> 26
# C25_B02_002_500860.json : leaf_cnt --> 7
# C25_B02_002_500860.json : leaf_width --> 8.5
# C25_B02_002_500860.json : leaf_length --> 11.3
# C25_B02_002_500860.json : stem_thick --> 14.5
# C25_B02_002_500860.json : bloom1_date --> 2021-09-29
# C25_B02_002_500860.json : fr1_cnt --> 1
# C25_B02_002_500860.json : fr_weight --> 9
# C25_B02_002_572517.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_572517.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_572517.json : measured_date --> 2021-12-01
# C25_B02_002_572517.json : stem_length --> 26
# C25_B02_002_572517.json : leaf_cnt --> 8
# C25_B02_002_572517.json : leaf_width --> 8.5
# C25_B02_002_572517.json : leaf_length --> 11.6
# C25_B02_002_572517.json : stem_thick --> 13.8
# C25_B02_002_572517.json : bloom1_date --> 2021-09-29
# C25_B02_002_572517.json : fr1_cnt --> 1
# C25_B02_002_572517.json : fr_weight --> 7
# C25_B02_002_572580.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_572580.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_572580.json : measured_date --> 2021-12-01
# C25_B02_002_572580.json : stem_length --> 26
# C25_B02_002_572580.json : leaf_cnt --> 8
# C25_B02_002_572580.json : leaf_width --> 8.5
# C25_B02_002_572580.json : leaf_length --> 11.6
# C25_B02_002_572580.json : stem_thick --> 13.8
# C25_B02_002_572580.json : bloom1_date --> 2021-09-29
# C25_B02_002_572580.json : fr1_cnt --> 1
# C25_B02_002_572580.json : fr_weight --> 7
# C25_B02_002_601197.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_601197.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_601197.json : measured_date --> 2021-12-08
# C25_B02_002_601197.json : stem_length --> 25.7
# C25_B02_002_601197.json : leaf_cnt --> 9
# C25_B02_002_601197.json : leaf_width --> 8.3
# C25_B02_002_601197.json : leaf_length --> 11.5
# C25_B02_002_601197.json : stem_thick --> 16.1
# C25_B02_002_601197.json : bloom1_date --> 2021-09-29
# C25_B02_002_601224.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_601224.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_601224.json : measured_date --> 2021-12-08
# C25_B02_002_601224.json : stem_length --> 25.7
# C25_B02_002_601224.json : leaf_cnt --> 9
# C25_B02_002_601224.json : leaf_width --> 8.3
# C25_B02_002_601224.json : leaf_length --> 11.5
# C25_B02_002_601224.json : stem_thick --> 16.1
# C25_B02_002_601224.json : bloom1_date --> 2021-09-29
# C25_B02_002_648358.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_648358.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_648358.json : measured_date --> 2021-12-22
# C25_B02_002_648358.json : stem_length --> 24.5
# C25_B02_002_648358.json : leaf_cnt --> 12
# C25_B02_002_648358.json : leaf_width --> 6.7
# C25_B02_002_648358.json : leaf_length --> 9
# C25_B02_002_648358.json : stem_thick --> 16.7
# C25_B02_002_648358.json : bloom1_date --> 2021-09-29
# C25_B02_002_648366.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_648366.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_648366.json : measured_date --> 2021-12-22
# C25_B02_002_648366.json : stem_length --> 24.5
# C25_B02_002_648366.json : leaf_cnt --> 12
# C25_B02_002_648366.json : leaf_width --> 6.7
# C25_B02_002_648366.json : leaf_length --> 9
# C25_B02_002_648366.json : stem_thick --> 16.7
# C25_B02_002_648366.json : bloom1_date --> 2021-09-29
# C25_B02_002_738978.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_738978.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_738978.json : measured_date --> 2022-01-05
# C25_B02_002_738978.json : stem_length --> 24.8
# C25_B02_002_738978.json : leaf_cnt --> 8
# C25_B02_002_738978.json : leaf_width --> 6.3
# C25_B02_002_738978.json : leaf_length --> 10.4
# C25_B02_002_738978.json : stem_thick --> 20
# C25_B02_002_738978.json : bloom1_date --> 2021-09-29
# C25_B02_002_781959.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_781959.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_002_781959.json : measured_date --> 2022-01-12
# C25_B02_002_781959.json : stem_length --> 24.4
# C25_B02_002_781959.json : leaf_cnt --> 8
# C25_B02_002_781959.json : leaf_width --> 6.3
# C25_B02_002_781959.json : leaf_length --> 10.2
# C25_B02_002_781959.json : stem_thick --> 15.8
# C25_B02_002_781959.json : bloom1_date --> 2021-09-29
# C25_B02_003_422472.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_422472.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_422472.json : measured_date --> 2021-10-13
# C25_B02_003_422472.json : stem_length --> 29
# C25_B02_003_422472.json : leaf_cnt --> 12
# C25_B02_003_422472.json : leaf_width --> 8.9
# C25_B02_003_422472.json : leaf_length --> 12.5
# C25_B02_003_422472.json : stem_thick --> 12.8
# C25_B02_003_422488.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_422488.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_422488.json : measured_date --> 2021-10-13
# C25_B02_003_422488.json : stem_length --> 29
# C25_B02_003_422488.json : leaf_cnt --> 12
# C25_B02_003_422488.json : leaf_width --> 8.9
# C25_B02_003_422488.json : leaf_length --> 12.5
# C25_B02_003_422488.json : stem_thick --> 12.8
# C25_B02_003_423435.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_423435.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_423435.json : measured_date --> 2021-10-27
# C25_B02_003_423435.json : stem_length --> 29
# C25_B02_003_423435.json : leaf_cnt --> 16
# C25_B02_003_423435.json : leaf_width --> 9
# C25_B02_003_423435.json : leaf_length --> 12.6
# C25_B02_003_423435.json : stem_thick --> 18.5
# C25_B02_003_424226.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_424226.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_424226.json : measured_date --> 2021-11-03
# C25_B02_003_424226.json : stem_length --> 29
# C25_B02_003_424226.json : leaf_cnt --> 19
# C25_B02_003_424226.json : leaf_width --> 9.1
# C25_B02_003_424226.json : leaf_length --> 13.1
# C25_B02_003_424226.json : stem_thick --> 14
# C25_B02_003_424226.json : bloom1_date --> 2021-09-08
# C25_B02_003_424226.json : fr_weight --> 11
# C25_B02_003_431727.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_431727.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_431727.json : measured_date --> 2021-11-03
# C25_B02_003_431727.json : stem_length --> 29
# C25_B02_003_431727.json : leaf_cnt --> 19
# C25_B02_003_431727.json : leaf_width --> 9.1
# C25_B02_003_431727.json : leaf_length --> 13.1
# C25_B02_003_431727.json : stem_thick --> 14
# C25_B02_003_431727.json : bloom1_date --> 2021-09-08
# C25_B02_003_431727.json : fr_weight --> 11
# C25_B02_003_446627.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_446627.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_446627.json : measured_date --> 2021-09-01
# C25_B02_003_446627.json : stem_length --> 40.3
# C25_B02_003_446627.json : leaf_cnt --> 5
# C25_B02_003_446627.json : leaf_width --> 6.1
# C25_B02_003_446627.json : leaf_length --> 9.4
# C25_B02_003_446627.json : stem_thick --> 13.5
# C25_B02_003_446659.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_446659.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_446659.json : measured_date --> 2021-09-01
# C25_B02_003_446659.json : stem_length --> 40.3
# C25_B02_003_446659.json : leaf_cnt --> 5
# C25_B02_003_446659.json : leaf_width --> 6.1
# C25_B02_003_446659.json : leaf_length --> 9.4
# C25_B02_003_446659.json : stem_thick --> 13.5
# C25_B02_003_446667.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_446667.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_446667.json : measured_date --> 2021-09-01
# C25_B02_003_446667.json : stem_length --> 40.3
# C25_B02_003_446667.json : leaf_cnt --> 5
# C25_B02_003_446667.json : leaf_width --> 6.1
# C25_B02_003_446667.json : leaf_length --> 9.4
# C25_B02_003_446667.json : stem_thick --> 13.5
# C25_B02_003_451456.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_451456.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_451456.json : measured_date --> 2021-09-23
# C25_B02_003_451456.json : stem_length --> 38.1
# C25_B02_003_451456.json : leaf_cnt --> 10
# C25_B02_003_451456.json : leaf_width --> 7.7
# C25_B02_003_451456.json : leaf_length --> 10.2
# C25_B02_003_451456.json : stem_thick --> 13.8
# C25_B02_003_451456.json : fr1_cnt --> 4
# C25_B02_003_451456.json : fr_weight --> 8
# C25_B02_003_452207.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_452207.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_452207.json : measured_date --> 2021-09-23
# C25_B02_003_452207.json : stem_length --> 38.1
# C25_B02_003_452207.json : leaf_cnt --> 10
# C25_B02_003_452207.json : leaf_width --> 7.7
# C25_B02_003_452207.json : leaf_length --> 10.2
# C25_B02_003_452207.json : stem_thick --> 13.8
# C25_B02_003_452207.json : fr1_cnt --> 4
# C25_B02_003_452207.json : fr_weight --> 8
# C25_B02_003_454210.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_454210.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_454210.json : measured_date --> 2021-09-29
# C25_B02_003_454210.json : stem_length --> 39
# C25_B02_003_454210.json : leaf_cnt --> 11
# C25_B02_003_454210.json : leaf_width --> 7.8
# C25_B02_003_454210.json : leaf_length --> 10.2
# C25_B02_003_454210.json : stem_thick --> 13.4
# C25_B02_003_454210.json : fr1_cnt --> 3
# C25_B02_003_454240.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_454240.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_454240.json : measured_date --> 2021-09-29
# C25_B02_003_454240.json : stem_length --> 39
# C25_B02_003_454240.json : leaf_cnt --> 11
# C25_B02_003_454240.json : leaf_width --> 7.8
# C25_B02_003_454240.json : leaf_length --> 10.2
# C25_B02_003_454240.json : stem_thick --> 13.4
# C25_B02_003_454240.json : fr1_cnt --> 3
# C25_B02_003_507908.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_507908.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_507908.json : measured_date --> 2021-11-17
# C25_B02_003_507908.json : stem_length --> 26
# C25_B02_003_507908.json : leaf_cnt --> 14
# C25_B02_003_507908.json : leaf_width --> 8.1
# C25_B02_003_507908.json : leaf_length --> 11.3
# C25_B02_003_507908.json : stem_thick --> 17
# C25_B02_003_507908.json : bloom1_date --> 2021-09-08
# C25_B02_003_507908.json : bloom2_date --> 2021-11-10
# C25_B02_003_507908.json : fr1_cnt --> 2
# C25_B02_003_549267.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_549267.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_549267.json : measured_date --> 2021-11-24
# C25_B02_003_549267.json : stem_length --> 26.2
# C25_B02_003_549267.json : leaf_cnt --> 15
# C25_B02_003_549267.json : leaf_width --> 10.8
# C25_B02_003_549267.json : leaf_length --> 10.3
# C25_B02_003_549267.json : stem_thick --> 19.4
# C25_B02_003_549267.json : bloom1_date --> 2021-09-08
# C25_B02_003_549267.json : bloom2_date --> 2021-11-10
# C25_B02_003_549267.json : fr2_cnt --> 3
# C25_B02_003_572514.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_572514.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_572514.json : measured_date --> 2021-12-01
# C25_B02_003_572514.json : stem_length --> 26.7
# C25_B02_003_572514.json : leaf_cnt --> 16
# C25_B02_003_572514.json : leaf_width --> 8.3
# C25_B02_003_572514.json : leaf_length --> 11.4
# C25_B02_003_572514.json : stem_thick --> 17.8
# C25_B02_003_572514.json : bloom1_date --> 2021-09-08
# C25_B02_003_572514.json : bloom2_date --> 2021-11-10
# C25_B02_003_572514.json : fr2_cnt --> 6
# C25_B02_003_572514.json : fr_weight --> 14
# C25_B02_003_572528.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_572528.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_572528.json : measured_date --> 2021-12-01
# C25_B02_003_572528.json : stem_length --> 26.7
# C25_B02_003_572528.json : leaf_cnt --> 16
# C25_B02_003_572528.json : leaf_width --> 8.3
# C25_B02_003_572528.json : leaf_length --> 11.4
# C25_B02_003_572528.json : stem_thick --> 17.8
# C25_B02_003_572528.json : bloom1_date --> 2021-09-08
# C25_B02_003_572528.json : bloom2_date --> 2021-11-10
# C25_B02_003_572528.json : fr2_cnt --> 6
# C25_B02_003_572528.json : fr_weight --> 14
# C25_B02_003_594862.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_594862.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_594862.json : measured_date --> 2021-12-08
# C25_B02_003_594862.json : stem_length --> 27.4
# C25_B02_003_594862.json : leaf_cnt --> 16
# C25_B02_003_594862.json : leaf_width --> 9
# C25_B02_003_594862.json : leaf_length --> 12.3
# C25_B02_003_594862.json : stem_thick --> 18.8
# C25_B02_003_594862.json : bloom1_date --> 2021-09-08
# C25_B02_003_594862.json : bloom2_date --> 2021-11-10
# C25_B02_003_594862.json : fr1_cnt --> 4
# C25_B02_003_594862.json : fr2_cnt --> 7
# C25_B02_003_594862.json : fr_weight --> 33
# C25_B02_003_601185.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_601185.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_601185.json : measured_date --> 2021-12-08
# C25_B02_003_601185.json : stem_length --> 27.4
# C25_B02_003_601185.json : leaf_cnt --> 16
# C25_B02_003_601185.json : leaf_width --> 9
# C25_B02_003_601185.json : leaf_length --> 12.3
# C25_B02_003_601185.json : stem_thick --> 18.8
# C25_B02_003_601185.json : bloom1_date --> 2021-09-08
# C25_B02_003_601185.json : bloom2_date --> 2021-11-10
# C25_B02_003_601185.json : fr1_cnt --> 4
# C25_B02_003_601185.json : fr2_cnt --> 7
# C25_B02_003_601185.json : fr_weight --> 33
# C25_B02_003_622112.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_622112.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_622112.json : measured_date --> 2021-12-15
# C25_B02_003_622112.json : stem_length --> 27
# C25_B02_003_622112.json : leaf_cnt --> 13
# C25_B02_003_622112.json : leaf_width --> 8.8
# C25_B02_003_622112.json : leaf_length --> 10.7
# C25_B02_003_622112.json : stem_thick --> 17.5
# C25_B02_003_622112.json : bloom1_date --> 2021-09-08
# C25_B02_003_622112.json : bloom2_date --> 2021-11-10
# C25_B02_003_622112.json : fr1_cnt --> 4
# C25_B02_003_622112.json : fr2_cnt --> 4
# C25_B02_003_670639.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_670639.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_670639.json : measured_date --> 2021-12-22
# C25_B02_003_670639.json : stem_length --> 27
# C25_B02_003_670639.json : leaf_cnt --> 8
# C25_B02_003_670639.json : leaf_width --> 8.8
# C25_B02_003_670639.json : leaf_length --> 10.9
# C25_B02_003_670639.json : stem_thick --> 18.3
# C25_B02_003_670639.json : bloom1_date --> 2021-09-08
# C25_B02_003_670639.json : bloom2_date --> 2021-11-10
# C25_B02_003_670639.json : fr1_cnt --> 4
# C25_B02_003_670639.json : fr2_cnt --> 2
# C25_B02_003_670639.json : fr_weight --> 31
# C25_B02_003_693959.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_693959.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_693959.json : measured_date --> 2021-12-29
# C25_B02_003_693959.json : stem_length --> 17.5
# C25_B02_003_693959.json : leaf_cnt --> 13
# C25_B02_003_693959.json : leaf_width --> 8.8
# C25_B02_003_693959.json : leaf_length --> 11
# C25_B02_003_693959.json : stem_thick --> 18.5
# C25_B02_003_693959.json : bloom1_date --> 2021-09-08
# C25_B02_003_693959.json : bloom2_date --> 2021-11-10
# C25_B02_003_693959.json : bloom3_date --> 2021-12-09
# C25_B02_003_693959.json : fr1_cnt --> 4
# C25_B02_003_693959.json : fr_weight --> 29
# C25_B02_003_738967.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_738967.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_003_738967.json : measured_date --> 2022-01-05
# C25_B02_003_738967.json : stem_length --> 27.2
# C25_B02_003_738967.json : leaf_cnt --> 13
# C25_B02_003_738967.json : leaf_width --> 8.6
# C25_B02_003_738967.json : leaf_length --> 10.9
# C25_B02_003_738967.json : stem_thick --> 19
# C25_B02_003_738967.json : bloom1_date --> 2021-09-08
# C25_B02_003_738967.json : bloom2_date --> 2021-11-10
# ...
# C24_B02_003_703594.json : measured_date --> 2021-12-29
# C24_B02_003_703594.json : stem_length --> 26.5
# C24_B02_003_703594.json : leaf_cnt --> 7
# C24_B02_003_703594.json : leaf_width --> 9.7
# C24_B02_003_703594.json : leaf_length --> 12.6
# C24_B02_003_703594.json : stem_thick --> 22
# C24_B02_003_703594.json : bloom1_date --> 2021-11-03
# C24_B02_003_739094.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_003_739094.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_003_739094.json : measured_date --> 2022-01-05
# C24_B02_003_739094.json : stem_length --> 27.1
# C24_B02_003_739094.json : leaf_cnt --> 8
# C24_B02_003_739094.json : leaf_width --> 9.2
# C24_B02_003_739094.json : leaf_length --> 11
# C24_B02_003_739094.json : stem_thick --> 17.2
# C24_B02_003_739094.json : bloom1_date --> 2021-11-03
# C24_B02_004_426348.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_426348.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_426348.json : measured_date --> 2021-10-27
# C24_B02_004_426348.json : stem_length --> 34.3
# C24_B02_004_426348.json : leaf_cnt --> 15
# C24_B02_004_426348.json : leaf_width --> 9.5
# C24_B02_004_426348.json : leaf_length --> 13.8
# C24_B02_004_426348.json : stem_thick --> 17.6
# C24_B02_004_427021.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_427021.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_427021.json : measured_date --> 2021-11-03
# C24_B02_004_427021.json : stem_length --> 34.5
# C24_B02_004_427021.json : leaf_cnt --> 16
# C24_B02_004_427021.json : leaf_width --> 10.3
# C24_B02_004_427021.json : leaf_length --> 13.6
# C24_B02_004_427021.json : stem_thick --> 14.5
# C24_B02_004_427021.json : bloom1_date --> 2021-11-03
# C24_B02_004_427049.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_427049.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_427049.json : measured_date --> 2021-11-03
# C24_B02_004_427049.json : stem_length --> 34.5
# C24_B02_004_427049.json : leaf_cnt --> 16
# C24_B02_004_427049.json : leaf_width --> 10.3
# C24_B02_004_427049.json : leaf_length --> 13.6
# C24_B02_004_427049.json : stem_thick --> 14.5
# C24_B02_004_427049.json : bloom1_date --> 2021-11-03
# C24_B02_004_456463.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_456463.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_456463.json : measured_date --> 2021-09-01
# C24_B02_004_456463.json : stem_length --> 27.1
# C24_B02_004_456463.json : leaf_cnt --> 5
# C24_B02_004_456463.json : leaf_width --> 7.2
# C24_B02_004_456463.json : leaf_length --> 10
# C24_B02_004_456463.json : stem_thick --> 11.3
# C24_B02_004_457702.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_457702.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_457702.json : measured_date --> 2021-09-08
# C24_B02_004_457702.json : stem_length --> 27.1
# C24_B02_004_457702.json : leaf_cnt --> 8
# C24_B02_004_457702.json : leaf_width --> 9.1
# C24_B02_004_457702.json : leaf_length --> 13.3
# C24_B02_004_457702.json : stem_thick --> 12
# C24_B02_004_457709.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_457709.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_457709.json : measured_date --> 2021-09-08
# C24_B02_004_457709.json : stem_length --> 27.1
# C24_B02_004_457709.json : leaf_cnt --> 8
# C24_B02_004_457709.json : leaf_width --> 9.1
# C24_B02_004_457709.json : leaf_length --> 13.3
# C24_B02_004_457709.json : stem_thick --> 12
# C24_B02_004_458683.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_458683.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_458683.json : measured_date --> 2021-09-23
# C24_B02_004_458683.json : stem_length --> 27.7
# C24_B02_004_458683.json : leaf_cnt --> 12
# C24_B02_004_458683.json : leaf_width --> 9.3
# C24_B02_004_458683.json : leaf_length --> 13.9
# C24_B02_004_458683.json : stem_thick --> 13.8
# C24_B02_004_458709.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_458709.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_458709.json : measured_date --> 2021-09-23
# C24_B02_004_458709.json : stem_length --> 27.7
# C24_B02_004_458709.json : leaf_cnt --> 12
# C24_B02_004_458709.json : leaf_width --> 9.3
# C24_B02_004_458709.json : leaf_length --> 13.9
# C24_B02_004_458709.json : stem_thick --> 13.8
# C24_B02_004_460617.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_460617.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_460617.json : measured_date --> 2021-11-10
# C24_B02_004_460617.json : stem_length --> 35
# C24_B02_004_460617.json : leaf_cnt --> 16
# C24_B02_004_460617.json : leaf_width --> 10.4
# C24_B02_004_460617.json : leaf_length --> 13.5
# C24_B02_004_460617.json : stem_thick --> 18.3
# C24_B02_004_460617.json : bloom1_date --> 2021-11-03
# C24_B02_004_460617.json : fr1_cnt --> 1
# C24_B02_004_460650.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_460650.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_460650.json : measured_date --> 2021-11-10
# C24_B02_004_460650.json : stem_length --> 35
# C24_B02_004_460650.json : leaf_cnt --> 16
# C24_B02_004_460650.json : leaf_width --> 10.4
# C24_B02_004_460650.json : leaf_length --> 13.5
# C24_B02_004_460650.json : stem_thick --> 18.3
# C24_B02_004_460650.json : bloom1_date --> 2021-11-03
# C24_B02_004_460650.json : fr1_cnt --> 1
# C24_B02_004_460673.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_460673.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_460673.json : measured_date --> 2021-11-10
# C24_B02_004_460673.json : stem_length --> 35
# C24_B02_004_460673.json : leaf_cnt --> 16
# C24_B02_004_460673.json : leaf_width --> 10.4
# C24_B02_004_460673.json : leaf_length --> 13.5
# C24_B02_004_460673.json : stem_thick --> 18.3
# C24_B02_004_460673.json : bloom1_date --> 2021-11-03
# C24_B02_004_460673.json : fr1_cnt --> 1
# C24_B02_004_537987.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_537987.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_537987.json : measured_date --> 2021-11-24
# C24_B02_004_537987.json : stem_length --> 29.2
# C24_B02_004_537987.json : leaf_cnt --> 20
# C24_B02_004_537987.json : leaf_width --> 10.3
# C24_B02_004_537987.json : leaf_length --> 13.7
# C24_B02_004_537987.json : stem_thick --> 22.3
# C24_B02_004_537987.json : bloom1_date --> 2021-11-03
# C24_B02_004_537987.json : fr1_cnt --> 3
# C24_B02_004_573744.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_573744.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_573744.json : measured_date --> 2021-12-01
# C24_B02_004_573744.json : stem_length --> 29.2
# C24_B02_004_573744.json : leaf_cnt --> 16
# C24_B02_004_573744.json : leaf_width --> 10.7
# C24_B02_004_573744.json : leaf_length --> 13.5
# C24_B02_004_573744.json : stem_thick --> 16.6
# C24_B02_004_573744.json : bloom1_date --> 2021-11-03
# C24_B02_004_573744.json : fr1_cnt --> 4
# C24_B02_004_573744.json : fr_weight --> 20
# C24_B02_004_573839.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_573839.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_573839.json : measured_date --> 2021-12-01
# C24_B02_004_573839.json : stem_length --> 29.2
# C24_B02_004_573839.json : leaf_cnt --> 16
# C24_B02_004_573839.json : leaf_width --> 10.7
# C24_B02_004_573839.json : leaf_length --> 13.5
# C24_B02_004_573839.json : stem_thick --> 16.6
# C24_B02_004_573839.json : bloom1_date --> 2021-11-03
# C24_B02_004_573839.json : fr1_cnt --> 4
# C24_B02_004_573839.json : fr_weight --> 20
# C24_B02_004_606205.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_606205.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_606205.json : measured_date --> 2021-12-08
# C24_B02_004_606205.json : stem_length --> 29.6
# C24_B02_004_606205.json : leaf_cnt --> 15
# C24_B02_004_606205.json : leaf_width --> 10.5
# C24_B02_004_606205.json : leaf_length --> 13.8
# C24_B02_004_606205.json : stem_thick --> 16
# C24_B02_004_606205.json : bloom1_date --> 2021-11-03
# C24_B02_004_606205.json : fr1_cnt --> 5
# C24_B02_004_606205.json : fr_weight --> 16
# C24_B02_004_621917.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_621917.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_621917.json : measured_date --> 2021-12-15
# C24_B02_004_621917.json : stem_length --> 25.5
# C24_B02_004_621917.json : leaf_cnt --> 13
# C24_B02_004_621917.json : leaf_width --> 8
# C24_B02_004_621917.json : leaf_length --> 10.2
# C24_B02_004_621917.json : stem_thick --> 17.5
# C24_B02_004_621917.json : bloom1_date --> 2021-11-03
# C24_B02_004_621917.json : fr1_cnt --> 4
# C24_B02_004_621917.json : fr_weight --> 13
# C24_B02_004_648451.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_648451.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_004_648451.json : measured_date --> 2021-12-22
# C24_B02_004_648451.json : stem_length --> 24.5
# C24_B02_004_648451.json : leaf_cnt --> 14
# C24_B02_004_648451.json : leaf_width --> 7.3
# C24_B02_004_648451.json : leaf_length --> 9.7
# C24_B02_004_648451.json : stem_thick --> 16.9
# C24_B02_004_648451.json : bloom1_date --> 2021-11-03
# C24_B02_004_648451.json : fr1_cnt --> 2
# C24_B02_004_648451.json : fr_weight --> 24
# C24_B02_005_425222.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_425222.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_425222.json : measured_date --> 2021-10-13
# C24_B02_005_425222.json : stem_length --> 29.5
# C24_B02_005_425222.json : leaf_cnt --> 7
# C24_B02_005_425222.json : leaf_width --> 8.8
# C24_B02_005_425222.json : leaf_length --> 13.6
# C24_B02_005_425222.json : stem_thick --> 13.8
# C24_B02_005_425222.json : bloom1_date --> 2021-09-29
# C24_B02_005_425222.json : fr1_cnt --> 4
# C24_B02_005_425222.json : fr_weight --> 9
# C24_B02_005_425256.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_425256.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_425256.json : measured_date --> 2021-10-13
# C24_B02_005_425256.json : stem_length --> 29.5
# C24_B02_005_425256.json : leaf_cnt --> 7
# C24_B02_005_425256.json : leaf_width --> 8.8
# C24_B02_005_425256.json : leaf_length --> 13.6
# C24_B02_005_425256.json : stem_thick --> 13.8
# C24_B02_005_425256.json : bloom1_date --> 2021-09-29
# C24_B02_005_425256.json : fr1_cnt --> 4
# C24_B02_005_425256.json : fr_weight --> 9
# C24_B02_005_427020.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_427020.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C24_B02_005_427020.json : measured_date --> 2021-11-03
# C24_B02_005_427020.json : stem_length --> 28.4
# C24_B02_005_427020.json : leaf_cnt --> 9
# C24_B02_005_427020.json : leaf_width --> 8.8
# C24_B02_005_427020.json : leaf_length --> 13.5
# C24_B02_005_427020.json : stem_thick --> 13.8
# C24_B02_005_427020.json : bloom1_date --> 2021-09-29
# C24_B02_005_427020.json : fr1_cnt --> 7
# C24_B02_005_427020.json : fr_weight --> 5
# C25_B02_007_622102.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_007_622102.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_007_622102.json : measured_date --> 2021-12-15
# C25_B02_007_622102.json : stem_length --> 30.5
# C25_B02_007_622102.json : leaf_cnt --> 7
# C25_B02_007_622102.json : leaf_width --> 9.3
# C25_B02_007_622102.json : leaf_length --> 13.9
# C25_B02_007_622102.json : stem_thick --> 15.6
# C25_B02_007_622102.json : bloom1_date --> 2021-10-27
# C25_B02_007_622102.json : fr_weight --> 10
# C25_B02_007_622110.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_007_622110.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_007_622110.json : measured_date --> 2021-12-15
# C25_B02_007_622110.json : stem_length --> 30.5
# C25_B02_007_622110.json : leaf_cnt --> 7
# C25_B02_007_622110.json : leaf_width --> 9.3
# C25_B02_007_622110.json : leaf_length --> 13.9
# C25_B02_007_622110.json : stem_thick --> 15.6
# C25_B02_007_622110.json : bloom1_date --> 2021-10-27
# C25_B02_007_622110.json : fr_weight --> 10
# C25_B02_007_622134.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_007_622134.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_007_622134.json : measured_date --> 2021-12-15
# C25_B02_007_622134.json : stem_length --> 30.5
# C25_B02_007_622134.json : leaf_cnt --> 7
# C25_B02_007_622134.json : leaf_width --> 9.3
# C25_B02_007_622134.json : leaf_length --> 13.9
# C25_B02_007_622134.json : stem_thick --> 15.6
# C25_B02_007_622134.json : bloom1_date --> 2021-10-27
# C25_B02_007_622134.json : fr_weight --> 10
# C25_B02_007_622142.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_007_622142.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_007_622142.json : measured_date --> 2021-12-15
# C25_B02_007_622142.json : stem_length --> 30.5
# C25_B02_007_622142.json : leaf_cnt --> 7
# C25_B02_007_622142.json : leaf_width --> 9.3
# C25_B02_007_622142.json : leaf_length --> 13.9
# C25_B02_007_622142.json : stem_thick --> 15.6
# C25_B02_007_622142.json : bloom1_date --> 2021-10-27
# C25_B02_007_622142.json : fr_weight --> 10
# C25_B02_007_693965.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_007_693965.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_007_693965.json : measured_date --> 2021-12-29
# C25_B02_007_693965.json : stem_length --> 30.5
# C25_B02_007_693965.json : leaf_cnt --> 7
# C25_B02_007_693965.json : leaf_width --> 10.4
# C25_B02_007_693965.json : leaf_length --> 12.5
# C25_B02_007_693965.json : stem_thick --> 16
# C25_B02_007_693965.json : bloom1_date --> 2021-10-27
# C25_B02_007_703415.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_007_703415.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_007_703415.json : measured_date --> 2021-12-29
# C25_B02_007_703415.json : stem_length --> 30.5
# C25_B02_007_703415.json : leaf_cnt --> 7
# C25_B02_007_703415.json : leaf_width --> 10.4
# C25_B02_007_703415.json : leaf_length --> 12.5
# C25_B02_007_703415.json : stem_thick --> 16
# C25_B02_007_703415.json : bloom1_date --> 2021-10-27
# C25_B02_007_738926.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_007_738926.json : ['sr_value', 'cl_value', 'el_value', 'hl_value', 'pi_value', 'rp_value']
# C25_B02_007_738926.json : measured_date --> 2022-01-05
# C25_B02_007_738926.json : stem_length --> 30.5
# C25_B02_007_738926.json : leaf_cnt --> 8
# C25_B02_007_738926.json : leaf_width --> 9.2
# C25_B02_007_738926.json : leaf_length --> 14.5
# C25_B02_007_738926.json : stem_thick --> 20.8
# C25_B02_007_738926.json : bloom1_date --> 2021-10-27

# %%
df = pd.DataFrame(df_data)
df
# Out:
#                    fname  image_id farm_id crops_id crops_type growth_stage  \
# 0     C25_B02_003_423515    423515  AIF005  C25_B02      딸기 금실          수확기
# 1     C24_B02_005_455867    455867  AIF005  C24_B02      딸기 금실          정식기
# 2     C24_B02_005_455902    455902  AIF005  C24_B02      딸기 금실          정식기
# 3     C24_B02_005_455944    455944  AIF005  C24_B02      딸기 금실          정식기
# 4     C24_B02_005_455965    455965  AIF005  C24_B02      딸기 금실          정식기
# ...                  ...       ...     ...      ...        ...          ...
# 3020  C25_B02_007_703415    703415  AIF005  C25_B02      딸기 금실          출뢰기
# 3021  C25_B02_007_715784    715784  AIF005  C25_B02      딸기 금실          출뢰기
# 3022  C25_B02_007_715896    715896  AIF005  C25_B02      딸기 금실          출뢰기
# 3023  C25_B02_007_731337    731337  AIF005  C25_B02      딸기 금실          출뢰기
# 3024  C25_B02_007_738926    738926  AIF005  C25_B02      딸기 금실          출뢰기
#
#           c_date    c_time                                               env1  \
# 0     2021-10-28  17:19:57  {'farm_id': 'AIF005', 'receive_date': '2021-10...
# 1     2021-08-28  18:46:29  {'farm_id': 'AIF005', 'receive_date': '2021-08...
# 2     2021-08-28  13:46:29  {'farm_id': 'AIF005', 'receive_date': '2021-08...
# 3     2021-08-28  07:46:29  {'farm_id': 'AIF005', 'receive_date': '2021-08...
# 4     2021-08-27  16:46:29  {'farm_id': 'AIF005', 'receive_date': '2021-08...
# ...          ...       ...                                                ...
# 3020  2021-12-29  13:44:31  {'farm_id': 'AIF005', 'receive_date': '2021-12...
# 3021  2021-12-31  08:44:31  {'farm_id': 'AIF005', 'receive_date': '2021-12...
# 3022  2022-01-01  14:44:31  {'farm_id': 'AIF005', 'receive_date': '2022-01...
# 3023  2022-01-03  09:44:31  {'farm_id': 'AIF005', 'receive_date': '2022-01...
# 3024  2022-01-05  10:44:31  {'farm_id': 'AIF005', 'receive_date': '2022-01...
#
#                                                    env2  \
# 0     {'farm_id': 'AIF005', 'receive_date': '2021-10...
# 1     {'farm_id': 'AIF005', 'receive_date': '2021-08...
# 2     {'farm_id': 'AIF005', 'receive_date': '2021-08...
# 3     {'farm_id': 'AIF005', 'receive_date': '2021-08...
# 4     {'farm_id': 'AIF005', 'receive_date': '2021-08...
# ...                                                 ...
# 3020  {'farm_id': 'AIF005', 'receive_date': '2021-12...
# 3021  {'farm_id': 'AIF005', 'receive_date': '2021-12...
# 3022  {'farm_id': 'AIF005', 'receive_date': '2022-01...
# 3023  {'farm_id': 'AIF005', 'receive_date': '2022-01...
# 3024  {'farm_id': 'AIF005', 'receive_date': '2022-01...
#
#                                             growth_info  \
# 0     {'corps_id': 'C25_B02', 'measured_date': None,...
# 1     {'corps_id': 'C24_B02', 'measured_date': None,...
# 2     {'corps_id': 'C24_B02', 'measured_date': None,...
# 3     {'corps_id': 'C24_B02', 'measured_date': None,...
# 4     {'corps_id': 'C24_B02', 'measured_date': None,...
# ...                                                 ...
# 3020  {'corps_id': 'C25_B02', 'measured_date': '2021...
# 3021  {'corps_id': 'C25_B02', 'measured_date': None,...
# 3022  {'corps_id': 'C25_B02', 'measured_date': None,...
# 3023  {'corps_id': 'C25_B02', 'measured_date': None,...
# 3024  {'corps_id': 'C25_B02', 'measured_date': '2022...
#
#                                                etc_info  img_width  \
# 0     {'corps_id': 'C25_B02', 'create_date': '', 'in...       1279
# 1     {'corps_id': 'C24_B02', 'create_date': '', 'in...       1509
# 2     {'corps_id': 'C24_B02', 'create_date': '', 'in...       1509
# 3     {'corps_id': 'C24_B02', 'create_date': '', 'in...       1509
# 4     {'corps_id': 'C24_B02', 'create_date': '', 'in...       1509
# ...                                                 ...        ...
# 3020  {'corps_id': 'C25_B02', 'create_date': '', 'in...       1228
# 3021  {'corps_id': 'C25_B02', 'create_date': '', 'in...       1229
# 3022  {'corps_id': 'C25_B02', 'create_date': '', 'in...       1229
# 3023  {'corps_id': 'C25_B02', 'create_date': '', 'in...       1229
# 3024  {'corps_id': 'C25_B02', 'create_date': '', 'in...       1232
#
#       img_height  bbox_num                                        annotations  \
# 0           1846         4  [{'segmentation': [974.95, 750.08, 1065.6, 750...
# 1           2074        10  [{'segmentation': [1051.97, 353.79, 1072.78, 3...
# 2           2074         9  [{'segmentation': [518.9, 637.79, 552.78, 637....
# 3           2074         7  [{'segmentation': [630.78, 553.87, 867.58, 553...
# 4           2074         5  [{'segmentation': [1055.42, 345.51, 1078.63, 3...
# ...          ...       ...                                                ...
# 3020        1470         8  [{'segmentation': [501.2, 889.41, 594.15, 889....
# 3021        1472         7  [{'segmentation': [424.9, 900.26, 525.81, 900....
# 3022        1472         6  [{'segmentation': [335.17, 959.88, 452.02, 959...
# 3023        1472        10  [{'segmentation': [288.05, 839.03, 398.68, 839...
# 3024        1477        11  [{'segmentation': [179.9, 737.06, 251.8, 737.0...
#
#                                              categories
# 0     [{'id': 0, 'name': '화방', 'supercategory': 'non...
# 1     [{'id': 0, 'name': '줄기', 'supercategory': 'non...
# 2     [{'id': 0, 'name': '줄기', 'supercategory': 'non...
# 3     [{'id': 0, 'name': '잎', 'supercategory': 'none...
# 4     [{'id': 0, 'name': '줄기', 'supercategory': 'non...
# ...                                                 ...
# 3020  [{'id': 0, 'name': '과실', 'supercategory': 'non...
# 3021  [{'id': 0, 'name': '과실', 'supercategory': 'non...
# 3022  [{'id': 0, 'name': '과실', 'supercategory': 'non...
# 3023  [{'id': 0, 'name': '과실', 'supercategory': 'non...
# 3024  [{'id': 0, 'name': '줄기', 'supercategory': 'non...
#
# [3025 rows x 17 columns]

# %%
df.to_csv("/content/drive/MyDrive/DLP/valid_meta_data.csv", index=False)

# %%
annot_df = pd.DataFrame(annot_data)
annot_df
# Out:
#        image_id               fname  \
# 0        423515  C25_B02_003_423515
# 1        423515  C25_B02_003_423515
# 2        423515  C25_B02_003_423515
# 3        423515  C25_B02_003_423515
# 4        455867  C24_B02_005_455867
# ...         ...                 ...
# 21696    738926  C25_B02_007_738926
# 21697    738926  C25_B02_007_738926
# 21698    738926  C25_B02_007_738926
# 21699    738926  C25_B02_007_738926
# 21700    738926  C25_B02_007_738926
#
#                                                  segment      area  \
# 0      [974.95, 750.08, 1065.6, 750.08, 1065.6, 842.9...   8419.57
# 1      [937.58, 804.96, 1054.86, 804.96, 1054.86, 922...  13830.83
# 2      [1155.81, 536.57, 1210.66, 536.57, 1210.66, 68...   8027.66
# 3      [445.45, 896.41, 592.54, 896.41, 592.54, 1200....  44718.40
# 4      [1051.97, 353.79, 1072.78, 353.79, 1072.78, 68...   6844.82
# ...                                                  ...       ...
# 21696  [393.07, 596.18, 515.39, 596.18, 515.39, 734.2...  16887.49
# 21697  [623.54, 957.08, 714.9, 957.08, 714.9, 1006.6,...   4524.14
# 21698  [591.69, 1004.44, 669.78, 1004.44, 669.78, 105...   3693.65
# 21699  [466.08, 952.65, 572.48, 952.65, 572.48, 1054....  10874.08
# 21700  [546.13, 927.42, 629.53, 927.42, 629.53, 1008....   6751.23
#
#                                    bbox category
# 0        [974.95, 750.08, 90.65, 92.88]       화방
# 1      [937.58, 804.96, 117.28, 117.93]       화방
# 2      [1155.81, 536.57, 54.86, 146.33]       줄기
# 3          [445.45, 896.41, 147.1, 304]        잎
# 4      [1051.97, 353.79, 20.81, 328.92]       줄기
# ...                                 ...      ...
# 21696  [393.07, 596.18, 122.32, 138.06]        잎
# 21697    [623.54, 957.08, 91.36, 49.52]       과실
# 21698    [591.69, 1004.44, 78.09, 47.3]       과실
# 21699    [466.08, 952.65, 106.4, 102.2]       과실
# 21700     [546.13, 927.42, 83.4, 80.95]       과실
#
# [21701 rows x 6 columns]

# %%
annot_df.to_csv("/content/drive/MyDrive/DLP/valid_annot_data.csv", index=False)

# %%
len(exinfo_json)
# Out:
# 354

# %%
ex_df = df[df['fname'].isin(exinfo_json)]
ex_df
# Out:
#                    fname  image_id farm_id crops_id crops_type growth_stage  \
# 15    C24_B02_005_457647    457647  AIF005  C24_B02      딸기 금실          출뢰기
# 16    C24_B02_005_457682    457682  AIF005  C24_B02      딸기 금실          출뢰기
# 17    C24_B02_005_457703    457703  AIF005  C24_B02      딸기 금실          출뢰기
# 20    C24_B02_005_457846    457846  AIF005  C24_B02      딸기 금실          출뢰기
# 21    C24_B02_005_457871    457871  AIF005  C24_B02      딸기 금실          출뢰기
# ...                  ...       ...     ...      ...        ...          ...
# 3006  C25_B02_007_622134    622134  AIF005  C25_B02      딸기 금실          수확기
# 3007  C25_B02_007_622142    622142  AIF005  C25_B02      딸기 금실          수확기
# 3019  C25_B02_007_693965    693965  AIF005  C25_B02      딸기 금실          출뢰기
# 3020  C25_B02_007_703415    703415  AIF005  C25_B02      딸기 금실          출뢰기
# 3024  C25_B02_007_738926    738926  AIF005  C25_B02      딸기 금실          출뢰기
#
#           c_date    c_time                                               env1  \
# 15    2021-09-08  09:46:29  {'farm_id': 'AIF005', 'receive_date': '2021-09...
# 16    2021-09-08  13:46:29  {'farm_id': 'AIF005', 'receive_date': '2021-09...
# 17    2021-09-08  17:46:29  {'farm_id': 'AIF005', 'receive_date': '2021-09...
# 20    2021-09-15  08:46:29  {'farm_id': 'AIF005', 'receive_date': '2021-09...
# 21    2021-09-15  12:46:29  {'farm_id': 'AIF005', 'receive_date': '2021-09...
# ...          ...       ...                                                ...
# 3006  2021-12-15  15:44:31  {'farm_id': 'AIF005', 'receive_date': '2021-12...
# 3007  2021-12-15  16:44:31  {'farm_id': 'AIF005', 'receive_date': '2021-12...
# 3019  2021-12-29  10:44:31  {'farm_id': 'AIF005', 'receive_date': '2021-12...
# 3020  2021-12-29  13:44:31  {'farm_id': 'AIF005', 'receive_date': '2021-12...
# 3024  2022-01-05  10:44:31  {'farm_id': 'AIF005', 'receive_date': '2022-01...
#
#                                                    env2  \
# 15    {'farm_id': 'AIF005', 'receive_date': '2021-09...
# 16    {'farm_id': 'AIF005', 'receive_date': '2021-09...
# 17    {'farm_id': 'AIF005', 'receive_date': '2021-09...
# 20    {'farm_id': 'AIF005', 'receive_date': '2021-09...
# 21    {'farm_id': 'AIF005', 'receive_date': '2021-09...
# ...                                                 ...
# 3006  {'farm_id': 'AIF005', 'receive_date': '2021-12...
# 3007  {'farm_id': 'AIF005', 'receive_date': '2021-12...
# 3019  {'farm_id': 'AIF005', 'receive_date': '2021-12...
# 3020  {'farm_id': 'AIF005', 'receive_date': '2021-12...
# 3024  {'farm_id': 'AIF005', 'receive_date': '2022-01...
#
#                                             growth_info  \
# 15    {'corps_id': 'C24_B02', 'measured_date': '2021...
# 16    {'corps_id': 'C24_B02', 'measured_date': '2021...
# 17    {'corps_id': 'C24_B02', 'measured_date': '2021...
# 20    {'corps_id': 'C24_B02', 'measured_date': '2021...
# 21    {'corps_id': 'C24_B02', 'measured_date': '2021...
# ...                                                 ...
# 3006  {'corps_id': 'C25_B02', 'measured_date': '2021...
# 3007  {'corps_id': 'C25_B02', 'measured_date': '2021...
# 3019  {'corps_id': 'C25_B02', 'measured_date': '2021...
# 3020  {'corps_id': 'C25_B02', 'measured_date': '2021...
# 3024  {'corps_id': 'C25_B02', 'measured_date': '2022...
#
#                                                etc_info  img_width  \
# 15    {'corps_id': 'C24_B02', 'create_date': '', 'in...       1532
# 16    {'corps_id': 'C24_B02', 'create_date': '', 'in...       1532
# 17    {'corps_id': 'C24_B02', 'create_date': '', 'in...       1532
# 20    {'corps_id': 'C24_B02', 'create_date': '', 'in...       1531
# 21    {'corps_id': 'C24_B02', 'create_date': '', 'in...       1531
# ...                                                 ...        ...
# 3006  {'corps_id': 'C25_B02', 'create_date': '', 'in...       1154
# 3007  {'corps_id': 'C25_B02', 'create_date': '', 'in...       1154
# 3019  {'corps_id': 'C25_B02', 'create_date': '', 'in...       1228
# 3020  {'corps_id': 'C25_B02', 'create_date': '', 'in...       1228
# 3024  {'corps_id': 'C25_B02', 'create_date': '', 'in...       1232
#
#       img_height  bbox_num                                        annotations  \
# 15          2096         4  [{'segmentation': [487.58, 486.96, 716, 486.96...
# 16          2096         5  [{'segmentation': [707.06, 1020.1, 894.59, 102...
# 17          2096         5  [{'segmentation': [847.06, 428.14, 1058.19, 42...
# 20          2096         4  [{'segmentation': [761.26, 1477.93, 1001.93, 1...
# 21          2096         4  [{'segmentation': [706, 508.61, 886.76, 508.61...
# ...          ...       ...                                                ...
# 3006        1759        10  [{'segmentation': [201.88, 578.45, 371.61, 578...
# 3007        1759         6  [{'segmentation': [506.83, 834.03, 590.99, 834...
# 3019        1470         5  [{'segmentation': [589.71, 458.09, 896.11, 458...
# 3020        1470         8  [{'segmentation': [501.2, 889.41, 594.15, 889....
# 3024        1477        11  [{'segmentation': [179.9, 737.06, 251.8, 737.0...
#
#                                              categories
# 15    [{'id': 0, 'name': '잎', 'supercategory': 'none...
# 16    [{'id': 0, 'name': '잎', 'supercategory': 'none...
# 17    [{'id': 0, 'name': '잎', 'supercategory': 'none...
# 20    [{'id': 0, 'name': '잎', 'supercategory': 'none...
# 21    [{'id': 0, 'name': '줄기', 'supercategory': 'non...
# ...                                                 ...
# 3006  [{'id': 0, 'name': '잎', 'supercategory': 'none...
# 3007  [{'id': 0, 'name': '과실', 'supercategory': 'non...
# 3019  [{'id': 0, 'name': '줄기', 'supercategory': 'non...
# 3020  [{'id': 0, 'name': '과실', 'supercategory': 'non...
# 3024  [{'id': 0, 'name': '줄기', 'supercategory': 'non...
#
# [354 rows x 17 columns]

# %%
ex_df.to_csv("/content/drive/MyDrive/DLP/valid_ex_data.csv")
